# %% [markdown]
# N_SPLITS=15、bagging_fraction=0.75、feature_fraction=0.75のLightGBMモデル（16seed Averaging）

# %% [markdown]
# # Libraries

# %%
# !pip3 uninstall --yes lightgbm && pip3 install --install-option=--gpu lightgbm
# Out:
# Uninstalling lightgbm-3.2.0:
#   Successfully uninstalled lightgbm-3.2.0
# /usr/local/lib/python3.7/dist-packages/pip/_internal/commands/install.py:283: UserWarning: Disabling all use of wheels due to the use of --build-options / --global-options / --install-options.
#   cmdoptions.check_install_build_global(options)
# Collecting lightgbm
#   Using cached https://files.pythonhosted.org/packages/d1/19/f19a8d12aecc7daaa5924c286c81e05ebb40ef3fe4cd4e33c8ed4e8db7ba/lightgbm-3.2.0.tar.gz
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm) (0.36.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.4.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /usr/local/lib/python3.7/dist-packages (from lightgbm) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.22.0->lightgbm) (1.0.1)
# Skipping wheel build for lightgbm, due to binaries being disabled for it.
# Installing collected packages: lightgbm
#     Running setup.py install for lightgbm ... done
# Successfully installed lightgbm-3.2.0

# %%
import warnings
warnings.filterwarnings('ignore')

import json
import pandas as pd
import numpy as np
import typing as tp
import time
from contextlib import contextmanager
from pathlib import Path
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import RidgeCV
import lightgbm as lgb

# %% [markdown]
# # Utils

# %%
DATADIR = Path('features')
OUTDIR = Path('stage1')

# %%
@contextmanager
def timer(logger=None, format_str='{:.3f}[s]', prefix=None, suffix=None):
    if prefix: format_str = str(prefix) + format_str
    if suffix: format_str = format_str + str(suffix)
    start = time.time()
    yield
    d = time.time() - start
    out_str = format_str.format(d)
    if logger:
        logger.info(out_str)
    else:
        print(out_str)

# %% [markdown]
# # Data Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "drive/My Drive/probspace_citations"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/probspace_citations

# %%
df = pd.read_csv(DATADIR / 'base_df.csv')
multiple_word_categories_features = pd.read_csv(DATADIR / 'multiple_word_categories_features.csv')
groupby_feat_csv = pd.read_csv(DATADIR / 'groupby_feat.csv')
ALL_w2v = pd.read_csv(DATADIR / 'ALL_w2v.csv')
ALL_svd_fastText = pd.read_csv(DATADIR / 'ALL_svd_fastText.csv')
#ALL_pca_fastText = pd.read_csv(DATADIR / 'ALL_pca_fastText.csv')
ALL_svd_SciBERT = pd.read_csv(DATADIR / 'ALL_svd_SciBERT.csv')
w2v = pd.read_csv(DATADIR / 'w2v.csv')
svd_fastText = pd.read_csv(DATADIR / 'svd_fastText.csv')
#pca_fastText = pd.read_csv(DATADIR / 'pca_fastText.csv')
svd_SciBERT = pd.read_csv(DATADIR / 'svd_SciBERT.csv')
#tfidf = pd.read_csv(DATADIR / 'tfidf.csv')

# %%
df = pd.merge(df, multiple_word_categories_features, on='id', how='left')
df = pd.merge(df, groupby_feat_csv, on='id', how='left')
df = pd.merge(df, ALL_w2v, on='id', how='left')
df = pd.merge(df, ALL_svd_fastText, on='id', how='left')
#df = pd.merge(df, ALL_pca_fastText, on='id', how='left')
df = pd.merge(df, ALL_svd_SciBERT, on='id', how='left')
df = pd.merge(df, w2v, on='id', how='left')
df = pd.merge(df, svd_fastText, on='id', how='left')
#df = pd.merge(df, pca_fastText, on='id', how='left')
df = pd.merge(df, svd_SciBERT, on='id', how='left')
#df = pd.merge(df, tfidf, on='id', how='left')

# %%
drop_cols = [col for col in df.columns[df.T.duplicated()]]
df = df.drop(columns=drop_cols) # 同じ列を削除

df = df.loc[:, df.nunique() > 1] # 1種類の値しかない列を削除

# %%
t = 15117
df_train_exists_cites = df[:t]
df_test = df[t:]

# %%
DROP_COLS = [
    'id',
    'submitter',
    'authors',
    'title',
    'comments',
    'journal-ref',
    'doi',
    'report-no',
    'categories',
    'license',
    'abstract',
    'versions',
    'update_date',
    'authors_parsed',
    'id_feat',
    'doi_feat_2',
]

TGT_COL = "cites"

# %%
X = df_train_exists_cites.drop(columns=DROP_COLS+['cites'])
X_test = df_test.drop(columns=DROP_COLS+['cites'])
y = np.log1p(df_train_exists_cites[TGT_COL])

print(f"train_feat: {X.shape}, test_feat: {X_test.shape}")
# Out:
# train_feat: (15117, 888), test_feat: (59084, 888)

# %% [markdown]
# # 1st Stage Model

# %% [markdown]
# ## Class

# %%
class TreeModel:
    """Wrapper for LightGBM/XGBoost/CATBoost"""
    def __init__(self, model_type: str):
        self.model_type = model_type
        self.trn_data = None
        self.val_data = None
        self.model = None

    def train(self,
              params: dict,
              X_train: pd.DataFrame, y_train: np.ndarray,
              X_val: pd.DataFrame, y_val: np.ndarray,
              train_weight: tp.Optional[np.ndarray] = None,
              val_weight: tp.Optional[np.ndarray] = None,
              train_params: dict = {}):
        if self.model_type == "lgb":
            self.trn_data = lgb.Dataset(X_train, label=y_train, weight=train_weight)
            self.val_data = lgb.Dataset(X_val, label=y_val, weight=val_weight)
            self.model = lgb.train(params=params,
                                   train_set=self.trn_data,
                                   valid_sets=[self.trn_data, self.val_data],
                                   categorical_feature = CATEGORICAL_COLS,
                                   **train_params)
        elif self.model_type == "xgb":
            self.trn_data = xgb.DMatrix(X_train, y_train, weight=train_weight)
            self.val_data = xgb.DMatrix(X_val, y_val, weight=val_weight)
            self.model = xgb.train(params=params,
                                   dtrain=self.trn_data,
                                   evals=[(self.trn_data, "train"), (self.val_data, "val")],
                                   **train_params)
        elif self.model_type == "cat":
            self.trn_data = Pool(X_train, label=y_train, group_id=[0] * len(X_train))
            self.val_data =  Pool(X_val, label=y_val, group_id=[0] * len(X_val))
            self.model = CatBoost(params)
            self.model.fit(
                self.trn_data, eval_set=[self.val_data], use_best_model=True, **train_params)
        else:
            raise NotImplementedError

    def predict(self, X: pd.DataFrame):
        if self.model_type == "lgb":
            return self.model.predict(
                X, num_iteration=self.model.best_iteration)
        elif self.model_type == "xgb":
            X_DM = xgb.DMatrix(X)
            return self.model.predict(
                X_DM, ntree_limit=self.model.best_ntree_limit)
        elif self.model_type == "cat":
            return self.model.predict(X)
        else:
            raise NotImplementedError

    @property
    def feature_names_(self):
        if self.model_type == "lgb":
            return self.model.feature_name()
        elif self.model_type == "xgb":
            return list(self.model.get_score(importance_type="gain").keys())
        elif self.model_type == "cat":
             return self.model.feature_names_
        else:
            raise NotImplementedError

    @property
    def feature_importances_(self):
        if self.model_type == "lgb":
            return self.model.feature_importance(importance_type="gain")
        elif self.model_type == "xgb":
            return list(self.model.get_score(importance_type="gain").values())
        elif self.model_type == "cat":
            return self.model.feature_importances_
        else:
            raise NotImplementedError

# %%
CATEGORICAL_COLS = [
    'doi_feat',
]

N_SPLITS = 15
RANDOM_SEED_LIST_LGB = [650,651,652,653,654,655,656,657,658,659,660,661,662,663,664,665]

MODEL_PARAMS = {
    "lgb": {
        'seed': RANDOM_SEED_LIST_LGB[1],
        'learning_rate': 0.01,
        'bagging_fraction': 0.75,
        'bagging_freq': 7,
        'feature_fraction': 0.75,
        'feature_pre_filter': False,
        'lambda_l1': 5.303273671011905e-07,
        'lambda_l2': 0.0036041492368018907,
        'metric': 'rmse',
        'min_child_samples': 24,
        'num_leaves': 36,
        'max_bin': 63,
        'objective': 'regression',
        'verbosity': -1,
        'device': 'gpu',
        'gpu_device_id': 0,
    },
}

TRAIN_PARAMS = {
    "lgb": {
        "num_boost_round": 20000,
        "early_stopping_rounds": 200,
        "verbose_eval": 100,
    },
}

# %%
def target_stratify_kfold(df, seed,n_bins=N_SPLITS*100, folds=N_SPLITS):
    _df = pd.DataFrame()
    _df["bins"] = pd.cut(df.cites, n_bins, labels=False)
    fold = np.zeros(len(df), dtype=int)
    skf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=seed)
    for i_fold, (_, val_idx) in enumerate(skf.split(_df.bins, _df.bins)):
        fold[val_idx] = i_fold
    return fold

# %%
def run_train_and_inference(X, X_test, y, use_model, model_params, train_params, seed_list, n_splits):
    
    oof_pred_arr = np.zeros(len(X))
    test_pred_arr = np.zeros(len(X_test))
    feature_importances = pd.DataFrame()
    score_list = []
    
    for seed in seed_list:
        if use_model == "cat":
            model_params['random_state'] = seed
        else:
            model_params["seed"] = seed
        folds_idx = target_stratify_kfold(df=df_train_exists_cites, seed=seed)
        tmp_oof_pred = np.zeros(len(X))
        tmp_test_pred = np.zeros(len(X_test))

        for fold in range(N_SPLITS):
            tr_idx = np.argwhere(folds_idx != fold).reshape(-1)
            va_idx = np.argwhere(folds_idx == fold).reshape(-1)
            X_trn, X_val = X.loc[tr_idx], X.loc[va_idx]
            y_trn, y_val = y.loc[tr_idx], y.loc[va_idx]

            model = TreeModel(model_type=use_model)
            with timer(prefix="Model training"):
                model.train(
                    params=model_params, X_train=X_trn, y_train=y_trn,
                    X_val=X_val, y_val=y_val, train_params=train_params)
            fi_tmp = pd.DataFrame()
            fi_tmp["feature"] = model.feature_names_
            fi_tmp["importance"] = model.feature_importances_
            fi_tmp["fold"] = fold
            fi_tmp["seed"] = seed
            feature_importances = feature_importances.append(fi_tmp)

            val_pred = model.predict(X_val)
            score = mean_squared_error(y_val, val_pred, squared=False)
            print(f"score: {score:.5f}")
            score_list.append([seed, fold, score])
            tmp_oof_pred[va_idx] = val_pred
            tmp_test_pred += model.predict(X_test)
            
        oof_score = mean_squared_error(y, tmp_oof_pred, squared=False)
        print(f"oof score: {oof_score: 5f}")
        score_list.append([seed, "oof", oof_score])

        oof_pred_arr += tmp_oof_pred
        test_pred_arr += tmp_test_pred / n_splits

    oof_pred_arr /= len(seed_list)
    test_pred_arr /= len(seed_list)
    
    oof_score = mean_squared_error(y, oof_pred_arr, squared=False)
    score_list.append(["avg", "oof", oof_score])
    score_df = pd.DataFrame(
        score_list, columns=["seed", "fold", "rmse score"])
    
    return oof_pred_arr, test_pred_arr, score_df, feature_importances

# %% [markdown]
# ## LightGBM

# %%
oof_pred_lgb, test_pred_lgb, score_lgb, feat_imps_lgb = run_train_and_inference(
    X, X_test, y, "lgb", MODEL_PARAMS["lgb"], TRAIN_PARAMS["lgb"], RANDOM_SEED_LIST_LGB, N_SPLITS)
# Out:
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.64376	valid_1's rmse: 0.657442
# [200]	training's rmse: 0.500711	valid_1's rmse: 0.538893
# [300]	training's rmse: 0.454744	valid_1's rmse: 0.516428
# [400]	training's rmse: 0.428922	valid_1's rmse: 0.510785
# [500]	training's rmse: 0.408589	valid_1's rmse: 0.507153
# [600]	training's rmse: 0.391159	valid_1's rmse: 0.505326
# [700]	training's rmse: 0.375561	valid_1's rmse: 0.504437
# [800]	training's rmse: 0.361337	valid_1's rmse: 0.504578
# [900]	training's rmse: 0.347808	valid_1's rmse: 0.504231
# [1000]	training's rmse: 0.33555	valid_1's rmse: 0.503792
# [1100]	training's rmse: 0.324046	valid_1's rmse: 0.503364
# [1200]	training's rmse: 0.313022	valid_1's rmse: 0.502955
# [1300]	training's rmse: 0.302691	valid_1's rmse: 0.502863
# [1400]	training's rmse: 0.292951	valid_1's rmse: 0.50292
# Early stopping, best iteration is:
# [1229]	training's rmse: 0.309936	valid_1's rmse: 0.502639
# Model training65.998[s]
# score: 0.50264
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644921	valid_1's rmse: 0.658154
# [200]	training's rmse: 0.502644	valid_1's rmse: 0.52613
# [300]	training's rmse: 0.456685	valid_1's rmse: 0.493623
# [400]	training's rmse: 0.43058	valid_1's rmse: 0.483915
# [500]	training's rmse: 0.410281	valid_1's rmse: 0.479876
# [600]	training's rmse: 0.392564	valid_1's rmse: 0.477537
# [700]	training's rmse: 0.376676	valid_1's rmse: 0.475979
# [800]	training's rmse: 0.362145	valid_1's rmse: 0.474746
# [900]	training's rmse: 0.348889	valid_1's rmse: 0.473668
# [1000]	training's rmse: 0.33663	valid_1's rmse: 0.472952
# [1100]	training's rmse: 0.325167	valid_1's rmse: 0.472586
# [1200]	training's rmse: 0.314372	valid_1's rmse: 0.472519
# [1300]	training's rmse: 0.304093	valid_1's rmse: 0.472005
# [1400]	training's rmse: 0.294303	valid_1's rmse: 0.471712
# [1500]	training's rmse: 0.284684	valid_1's rmse: 0.471508
# [1600]	training's rmse: 0.275828	valid_1's rmse: 0.471451
# [1700]	training's rmse: 0.266985	valid_1's rmse: 0.471264
# [1800]	training's rmse: 0.258856	valid_1's rmse: 0.471035
# [1900]	training's rmse: 0.250852	valid_1's rmse: 0.470797
# [2000]	training's rmse: 0.243235	valid_1's rmse: 0.470845
# [2100]	training's rmse: 0.23584	valid_1's rmse: 0.470834
# [2200]	training's rmse: 0.228745	valid_1's rmse: 0.470492
# [2300]	training's rmse: 0.221877	valid_1's rmse: 0.470443
# [2400]	training's rmse: 0.215278	valid_1's rmse: 0.470638
# Early stopping, best iteration is:
# [2286]	training's rmse: 0.222841	valid_1's rmse: 0.470369
# Model training109.006[s]
# score: 0.47037
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.643244	valid_1's rmse: 0.6761
# [200]	training's rmse: 0.499749	valid_1's rmse: 0.559633
# [300]	training's rmse: 0.454267	valid_1's rmse: 0.533378
# [400]	training's rmse: 0.428274	valid_1's rmse: 0.524662
# [500]	training's rmse: 0.407952	valid_1's rmse: 0.518841
# [600]	training's rmse: 0.390353	valid_1's rmse: 0.515542
# [700]	training's rmse: 0.375047	valid_1's rmse: 0.513077
# [800]	training's rmse: 0.360967	valid_1's rmse: 0.51217
# [900]	training's rmse: 0.347812	valid_1's rmse: 0.511
# [1000]	training's rmse: 0.335566	valid_1's rmse: 0.510348
# [1100]	training's rmse: 0.323917	valid_1's rmse: 0.509224
# [1200]	training's rmse: 0.312811	valid_1's rmse: 0.509483
# [1300]	training's rmse: 0.302564	valid_1's rmse: 0.509215
# [1400]	training's rmse: 0.292703	valid_1's rmse: 0.508969
# [1500]	training's rmse: 0.283274	valid_1's rmse: 0.508465
# [1600]	training's rmse: 0.274158	valid_1's rmse: 0.507882
# [1700]	training's rmse: 0.265653	valid_1's rmse: 0.507689
# [1800]	training's rmse: 0.257299	valid_1's rmse: 0.507744
# [1900]	training's rmse: 0.249382	valid_1's rmse: 0.507735
# Early stopping, best iteration is:
# [1728]	training's rmse: 0.263224	valid_1's rmse: 0.507584
# Model training85.945[s]
# score: 0.50758
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644217	valid_1's rmse: 0.668733
# [200]	training's rmse: 0.501618	valid_1's rmse: 0.541608
# [300]	training's rmse: 0.455939	valid_1's rmse: 0.512796
# [400]	training's rmse: 0.429858	valid_1's rmse: 0.503932
# [500]	training's rmse: 0.409653	valid_1's rmse: 0.499577
# [600]	training's rmse: 0.392107	valid_1's rmse: 0.497289
# [700]	training's rmse: 0.376453	valid_1's rmse: 0.496454
# [800]	training's rmse: 0.362012	valid_1's rmse: 0.495413
# [900]	training's rmse: 0.348727	valid_1's rmse: 0.495311
# [1000]	training's rmse: 0.336371	valid_1's rmse: 0.494816
# [1100]	training's rmse: 0.324749	valid_1's rmse: 0.495015
# [1200]	training's rmse: 0.313805	valid_1's rmse: 0.494554
# [1300]	training's rmse: 0.303455	valid_1's rmse: 0.494361
# [1400]	training's rmse: 0.293447	valid_1's rmse: 0.49425
# [1500]	training's rmse: 0.284053	valid_1's rmse: 0.494335
# Early stopping, best iteration is:
# [1392]	training's rmse: 0.294217	valid_1's rmse: 0.494185
# Model training72.615[s]
# score: 0.49418
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.64371	valid_1's rmse: 0.661891
# [200]	training's rmse: 0.500624	valid_1's rmse: 0.539902
# [300]	training's rmse: 0.454561	valid_1's rmse: 0.513446
# [400]	training's rmse: 0.428342	valid_1's rmse: 0.503867
# [500]	training's rmse: 0.408236	valid_1's rmse: 0.499256
# [600]	training's rmse: 0.3908	valid_1's rmse: 0.496258
# [700]	training's rmse: 0.375214	valid_1's rmse: 0.494298
# [800]	training's rmse: 0.360965	valid_1's rmse: 0.492814
# [900]	training's rmse: 0.347889	valid_1's rmse: 0.49206
# [1000]	training's rmse: 0.335392	valid_1's rmse: 0.491526
# [1100]	training's rmse: 0.323886	valid_1's rmse: 0.491599
# [1200]	training's rmse: 0.313344	valid_1's rmse: 0.491333
# [1300]	training's rmse: 0.302815	valid_1's rmse: 0.490919
# [1400]	training's rmse: 0.292852	valid_1's rmse: 0.490254
# [1500]	training's rmse: 0.283399	valid_1's rmse: 0.490245
# [1600]	training's rmse: 0.274408	valid_1's rmse: 0.489492
# [1700]	training's rmse: 0.265727	valid_1's rmse: 0.489021
# [1800]	training's rmse: 0.257502	valid_1's rmse: 0.488596
# [1900]	training's rmse: 0.24965	valid_1's rmse: 0.488734
# [2000]	training's rmse: 0.242023	valid_1's rmse: 0.488883
# Early stopping, best iteration is:
# [1810]	training's rmse: 0.256717	valid_1's rmse: 0.488558
# Model training89.725[s]
# score: 0.48856
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.646101	valid_1's rmse: 0.637725
# [200]	training's rmse: 0.503268	valid_1's rmse: 0.507364
# [300]	training's rmse: 0.45719	valid_1's rmse: 0.478127
# [400]	training's rmse: 0.430936	valid_1's rmse: 0.468473
# [500]	training's rmse: 0.410734	valid_1's rmse: 0.464356
# [600]	training's rmse: 0.392785	valid_1's rmse: 0.462553
# [700]	training's rmse: 0.376878	valid_1's rmse: 0.460949
# [800]	training's rmse: 0.362423	valid_1's rmse: 0.460463
# [900]	training's rmse: 0.349119	valid_1's rmse: 0.46005
# [1000]	training's rmse: 0.336601	valid_1's rmse: 0.459329
# [1100]	training's rmse: 0.325014	valid_1's rmse: 0.459389
# [1200]	training's rmse: 0.313861	valid_1's rmse: 0.459214
# [1300]	training's rmse: 0.303373	valid_1's rmse: 0.459732
# Early stopping, best iteration is:
# [1191]	training's rmse: 0.314895	valid_1's rmse: 0.459082
# Model training64.448[s]
# score: 0.45908
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645927	valid_1's rmse: 0.64179
# [200]	training's rmse: 0.502977	valid_1's rmse: 0.50314
# [300]	training's rmse: 0.457213	valid_1's rmse: 0.470948
# [400]	training's rmse: 0.431233	valid_1's rmse: 0.460451
# [500]	training's rmse: 0.410851	valid_1's rmse: 0.455889
# [600]	training's rmse: 0.393073	valid_1's rmse: 0.453497
# [700]	training's rmse: 0.377303	valid_1's rmse: 0.452586
# [800]	training's rmse: 0.36282	valid_1's rmse: 0.451903
# [900]	training's rmse: 0.349322	valid_1's rmse: 0.451648
# [1000]	training's rmse: 0.337003	valid_1's rmse: 0.450866
# [1100]	training's rmse: 0.325393	valid_1's rmse: 0.450363
# [1200]	training's rmse: 0.314479	valid_1's rmse: 0.45061
# [1300]	training's rmse: 0.304017	valid_1's rmse: 0.450607
# Early stopping, best iteration is:
# [1144]	training's rmse: 0.320525	valid_1's rmse: 0.450073
# Model training62.438[s]
# score: 0.45007
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.646315	valid_1's rmse: 0.644188
# [200]	training's rmse: 0.503233	valid_1's rmse: 0.511591
# [300]	training's rmse: 0.457083	valid_1's rmse: 0.481174
# [400]	training's rmse: 0.430937	valid_1's rmse: 0.472618
# [500]	training's rmse: 0.410458	valid_1's rmse: 0.469335
# [600]	training's rmse: 0.392896	valid_1's rmse: 0.46753
# [700]	training's rmse: 0.377126	valid_1's rmse: 0.466012
# [800]	training's rmse: 0.362647	valid_1's rmse: 0.465437
# [900]	training's rmse: 0.349209	valid_1's rmse: 0.465099
# [1000]	training's rmse: 0.336611	valid_1's rmse: 0.464409
# [1100]	training's rmse: 0.325032	valid_1's rmse: 0.463874
# [1200]	training's rmse: 0.314113	valid_1's rmse: 0.463703
# [1300]	training's rmse: 0.304003	valid_1's rmse: 0.463465
# [1400]	training's rmse: 0.293729	valid_1's rmse: 0.463833
# Early stopping, best iteration is:
# [1248]	training's rmse: 0.309187	valid_1's rmse: 0.462876
# Model training66.962[s]
# score: 0.46288
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645299	valid_1's rmse: 0.639822
# [200]	training's rmse: 0.502108	valid_1's rmse: 0.511179
# [300]	training's rmse: 0.456076	valid_1's rmse: 0.482684
# [400]	training's rmse: 0.430015	valid_1's rmse: 0.475355
# [500]	training's rmse: 0.409619	valid_1's rmse: 0.471808
# [600]	training's rmse: 0.39216	valid_1's rmse: 0.469807
# [700]	training's rmse: 0.376292	valid_1's rmse: 0.469103
# [800]	training's rmse: 0.361693	valid_1's rmse: 0.468933
# [900]	training's rmse: 0.348358	valid_1's rmse: 0.469273
# Early stopping, best iteration is:
# [759]	training's rmse: 0.367522	valid_1's rmse: 0.468786
# Model training45.971[s]
# score: 0.46879
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644965	valid_1's rmse: 0.650043
# [200]	training's rmse: 0.501369	valid_1's rmse: 0.52863
# [300]	training's rmse: 0.455384	valid_1's rmse: 0.503037
# [400]	training's rmse: 0.429137	valid_1's rmse: 0.495896
# [500]	training's rmse: 0.409013	valid_1's rmse: 0.493035
# [600]	training's rmse: 0.391479	valid_1's rmse: 0.492189
# [700]	training's rmse: 0.375774	valid_1's rmse: 0.49137
# [800]	training's rmse: 0.361402	valid_1's rmse: 0.490985
# [900]	training's rmse: 0.347928	valid_1's rmse: 0.490916
# [1000]	training's rmse: 0.335464	valid_1's rmse: 0.491425
# [1100]	training's rmse: 0.323854	valid_1's rmse: 0.491605
# Early stopping, best iteration is:
# [926]	training's rmse: 0.344631	valid_1's rmse: 0.490653
# Model training53.671[s]
# score: 0.49065
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.643995	valid_1's rmse: 0.649716
# [200]	training's rmse: 0.500767	valid_1's rmse: 0.530247
# [300]	training's rmse: 0.454974	valid_1's rmse: 0.505421
# [400]	training's rmse: 0.429312	valid_1's rmse: 0.498027
# [500]	training's rmse: 0.408656	valid_1's rmse: 0.494499
# [600]	training's rmse: 0.391074	valid_1's rmse: 0.492529
# [700]	training's rmse: 0.375453	valid_1's rmse: 0.491101
# [800]	training's rmse: 0.361042	valid_1's rmse: 0.490391
# [900]	training's rmse: 0.348005	valid_1's rmse: 0.489689
# [1000]	training's rmse: 0.335531	valid_1's rmse: 0.488954
# [1100]	training's rmse: 0.323988	valid_1's rmse: 0.48849
# [1200]	training's rmse: 0.313134	valid_1's rmse: 0.488864
# [1300]	training's rmse: 0.302794	valid_1's rmse: 0.488456
# [1400]	training's rmse: 0.292897	valid_1's rmse: 0.488031
# [1500]	training's rmse: 0.283463	valid_1's rmse: 0.48855
# [1600]	training's rmse: 0.274608	valid_1's rmse: 0.489017
# Early stopping, best iteration is:
# [1406]	training's rmse: 0.292312	valid_1's rmse: 0.487906
# Model training74.372[s]
# score: 0.48791
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.64302	valid_1's rmse: 0.665474
# [200]	training's rmse: 0.499569	valid_1's rmse: 0.556626
# [300]	training's rmse: 0.453663	valid_1's rmse: 0.536174
# [400]	training's rmse: 0.427575	valid_1's rmse: 0.529796
# [500]	training's rmse: 0.407591	valid_1's rmse: 0.52649
# [600]	training's rmse: 0.390209	valid_1's rmse: 0.524505
# [700]	training's rmse: 0.374495	valid_1's rmse: 0.52333
# [800]	training's rmse: 0.360157	valid_1's rmse: 0.523126
# [900]	training's rmse: 0.347249	valid_1's rmse: 0.522828
# [1000]	training's rmse: 0.334623	valid_1's rmse: 0.523104
# [1100]	training's rmse: 0.322763	valid_1's rmse: 0.522148
# [1200]	training's rmse: 0.311757	valid_1's rmse: 0.522255
# [1300]	training's rmse: 0.301452	valid_1's rmse: 0.522356
# Early stopping, best iteration is:
# [1155]	training's rmse: 0.316698	valid_1's rmse: 0.521786
# Model training48.095[s]
# score: 0.52179
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644648	valid_1's rmse: 0.674517
# [200]	training's rmse: 0.500662	valid_1's rmse: 0.546471
# [300]	training's rmse: 0.454792	valid_1's rmse: 0.516659
# [400]	training's rmse: 0.428687	valid_1's rmse: 0.507908
# [500]	training's rmse: 0.408337	valid_1's rmse: 0.503486
# [600]	training's rmse: 0.390628	valid_1's rmse: 0.501371
# [700]	training's rmse: 0.37472	valid_1's rmse: 0.500018
# [800]	training's rmse: 0.36046	valid_1's rmse: 0.499454
# [900]	training's rmse: 0.347371	valid_1's rmse: 0.499069
# [1000]	training's rmse: 0.334958	valid_1's rmse: 0.498283
# [1100]	training's rmse: 0.323525	valid_1's rmse: 0.497662
# [1200]	training's rmse: 0.312541	valid_1's rmse: 0.497136
# [1300]	training's rmse: 0.302265	valid_1's rmse: 0.496903
# [1400]	training's rmse: 0.292462	valid_1's rmse: 0.497109
# Early stopping, best iteration is:
# [1297]	training's rmse: 0.302546	valid_1's rmse: 0.496887
# Model training70.323[s]
# score: 0.49689
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644943	valid_1's rmse: 0.656153
# [200]	training's rmse: 0.501452	valid_1's rmse: 0.532667
# [300]	training's rmse: 0.45555	valid_1's rmse: 0.506467
# [400]	training's rmse: 0.429452	valid_1's rmse: 0.499508
# [500]	training's rmse: 0.409015	valid_1's rmse: 0.495972
# [600]	training's rmse: 0.391387	valid_1's rmse: 0.494042
# [700]	training's rmse: 0.375815	valid_1's rmse: 0.492685
# [800]	training's rmse: 0.36124	valid_1's rmse: 0.49137
# [900]	training's rmse: 0.347896	valid_1's rmse: 0.491284
# [1000]	training's rmse: 0.335531	valid_1's rmse: 0.491033
# [1100]	training's rmse: 0.32381	valid_1's rmse: 0.490526
# [1200]	training's rmse: 0.312725	valid_1's rmse: 0.490311
# [1300]	training's rmse: 0.302527	valid_1's rmse: 0.490561
# Early stopping, best iteration is:
# [1176]	training's rmse: 0.315276	valid_1's rmse: 0.490104
# Model training64.535[s]
# score: 0.49010
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.643784	valid_1's rmse: 0.668817
# [200]	training's rmse: 0.500505	valid_1's rmse: 0.552651
# [300]	training's rmse: 0.454774	valid_1's rmse: 0.528901
# [400]	training's rmse: 0.428955	valid_1's rmse: 0.522085
# [500]	training's rmse: 0.408383	valid_1's rmse: 0.51738
# [600]	training's rmse: 0.391029	valid_1's rmse: 0.514957
# [700]	training's rmse: 0.375277	valid_1's rmse: 0.51346
# [800]	training's rmse: 0.360991	valid_1's rmse: 0.512416
# [900]	training's rmse: 0.347437	valid_1's rmse: 0.511939
# [1000]	training's rmse: 0.335274	valid_1's rmse: 0.51124
# [1100]	training's rmse: 0.323707	valid_1's rmse: 0.511019
# [1200]	training's rmse: 0.312944	valid_1's rmse: 0.509871
# [1300]	training's rmse: 0.302343	valid_1's rmse: 0.509658
# [1400]	training's rmse: 0.292672	valid_1's rmse: 0.509722
# [1500]	training's rmse: 0.283278	valid_1's rmse: 0.509001
# [1600]	training's rmse: 0.274352	valid_1's rmse: 0.508613
# [1700]	training's rmse: 0.265526	valid_1's rmse: 0.50878
# [1800]	training's rmse: 0.257452	valid_1's rmse: 0.50917
# Early stopping, best iteration is:
# [1609]	training's rmse: 0.273581	valid_1's rmse: 0.508553
# Model training82.513[s]
# score: 0.50855
# oof score:  0.487068
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645464	valid_1's rmse: 0.643907
# [200]	training's rmse: 0.502438	valid_1's rmse: 0.513147
# [300]	training's rmse: 0.456786	valid_1's rmse: 0.484162
# [400]	training's rmse: 0.430887	valid_1's rmse: 0.475318
# [500]	training's rmse: 0.410642	valid_1's rmse: 0.470839
# [600]	training's rmse: 0.39312	valid_1's rmse: 0.468562
# [700]	training's rmse: 0.377463	valid_1's rmse: 0.46716
# [800]	training's rmse: 0.363076	valid_1's rmse: 0.466088
# [900]	training's rmse: 0.349823	valid_1's rmse: 0.465906
# [1000]	training's rmse: 0.337545	valid_1's rmse: 0.465451
# [1100]	training's rmse: 0.32589	valid_1's rmse: 0.465858
# [1200]	training's rmse: 0.314734	valid_1's rmse: 0.465518
# Early stopping, best iteration is:
# [1034]	training's rmse: 0.333459	valid_1's rmse: 0.465324
# Model training57.931[s]
# score: 0.46532
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645722	valid_1's rmse: 0.647993
# [200]	training's rmse: 0.502141	valid_1's rmse: 0.516114
# [300]	training's rmse: 0.456304	valid_1's rmse: 0.485614
# [400]	training's rmse: 0.430636	valid_1's rmse: 0.476582
# [500]	training's rmse: 0.4104	valid_1's rmse: 0.473387
# [600]	training's rmse: 0.392641	valid_1's rmse: 0.472231
# [700]	training's rmse: 0.376795	valid_1's rmse: 0.471779
# [800]	training's rmse: 0.36219	valid_1's rmse: 0.471721
# [900]	training's rmse: 0.348987	valid_1's rmse: 0.471165
# [1000]	training's rmse: 0.336632	valid_1's rmse: 0.471457
# [1100]	training's rmse: 0.325195	valid_1's rmse: 0.471597
# Early stopping, best iteration is:
# [917]	training's rmse: 0.346771	valid_1's rmse: 0.470949
# Model training53.047[s]
# score: 0.47095
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645472	valid_1's rmse: 0.656915
# [200]	training's rmse: 0.502144	valid_1's rmse: 0.527354
# [300]	training's rmse: 0.455977	valid_1's rmse: 0.495427
# [400]	training's rmse: 0.429825	valid_1's rmse: 0.485343
# [500]	training's rmse: 0.409383	valid_1's rmse: 0.481482
# [600]	training's rmse: 0.39172	valid_1's rmse: 0.479151
# [700]	training's rmse: 0.376032	valid_1's rmse: 0.47828
# [800]	training's rmse: 0.361687	valid_1's rmse: 0.477905
# [900]	training's rmse: 0.348396	valid_1's rmse: 0.477471
# [1000]	training's rmse: 0.335779	valid_1's rmse: 0.477058
# [1100]	training's rmse: 0.324106	valid_1's rmse: 0.477012
# [1200]	training's rmse: 0.312703	valid_1's rmse: 0.476889
# [1300]	training's rmse: 0.302071	valid_1's rmse: 0.477195
# [1400]	training's rmse: 0.29234	valid_1's rmse: 0.476538
# [1500]	training's rmse: 0.282929	valid_1's rmse: 0.475993
# [1600]	training's rmse: 0.27395	valid_1's rmse: 0.476373
# [1700]	training's rmse: 0.265204	valid_1's rmse: 0.475739
# [1800]	training's rmse: 0.257003	valid_1's rmse: 0.475609
# [1900]	training's rmse: 0.248926	valid_1's rmse: 0.475379
# [2000]	training's rmse: 0.241351	valid_1's rmse: 0.47524
# [2100]	training's rmse: 0.233962	valid_1's rmse: 0.475288
# Early stopping, best iteration is:
# [1972]	training's rmse: 0.243545	valid_1's rmse: 0.47508
# Model training96.569[s]
# score: 0.47508
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.64552	valid_1's rmse: 0.628595
# [200]	training's rmse: 0.503383	valid_1's rmse: 0.495666
# [300]	training's rmse: 0.457098	valid_1's rmse: 0.467242
# [400]	training's rmse: 0.431168	valid_1's rmse: 0.459717
# [500]	training's rmse: 0.410796	valid_1's rmse: 0.456948
# [600]	training's rmse: 0.393279	valid_1's rmse: 0.455642
# [700]	training's rmse: 0.377424	valid_1's rmse: 0.45537
# [800]	training's rmse: 0.3628	valid_1's rmse: 0.454946
# [900]	training's rmse: 0.349434	valid_1's rmse: 0.454998
# Early stopping, best iteration is:
# [788]	training's rmse: 0.364474	valid_1's rmse: 0.45474
# Model training47.733[s]
# score: 0.45474
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.643842	valid_1's rmse: 0.66512
# [200]	training's rmse: 0.499962	valid_1's rmse: 0.544869
# [300]	training's rmse: 0.454227	valid_1's rmse: 0.518921
# [400]	training's rmse: 0.428274	valid_1's rmse: 0.510371
# [500]	training's rmse: 0.407911	valid_1's rmse: 0.5076
# [600]	training's rmse: 0.390443	valid_1's rmse: 0.505744
# [700]	training's rmse: 0.374616	valid_1's rmse: 0.504701
# [800]	training's rmse: 0.360298	valid_1's rmse: 0.503744
# [900]	training's rmse: 0.34705	valid_1's rmse: 0.503691
# [1000]	training's rmse: 0.334755	valid_1's rmse: 0.503398
# [1100]	training's rmse: 0.323118	valid_1's rmse: 0.503259
# [1200]	training's rmse: 0.312316	valid_1's rmse: 0.502736
# [1300]	training's rmse: 0.301958	valid_1's rmse: 0.502233
# [1400]	training's rmse: 0.292051	valid_1's rmse: 0.501713
# [1500]	training's rmse: 0.282745	valid_1's rmse: 0.501377
# [1600]	training's rmse: 0.273797	valid_1's rmse: 0.501098
# [1700]	training's rmse: 0.265384	valid_1's rmse: 0.500669
# [1800]	training's rmse: 0.257003	valid_1's rmse: 0.500983
# [1900]	training's rmse: 0.249164	valid_1's rmse: 0.500783
# Early stopping, best iteration is:
# [1773]	training's rmse: 0.25925	valid_1's rmse: 0.500638
# Model training88.845[s]
# score: 0.50064
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.646827	valid_1's rmse: 0.62904
# [200]	training's rmse: 0.503897	valid_1's rmse: 0.494212
# [300]	training's rmse: 0.458151	valid_1's rmse: 0.465647
# [400]	training's rmse: 0.431651	valid_1's rmse: 0.457347
# [500]	training's rmse: 0.41121	valid_1's rmse: 0.453122
# [600]	training's rmse: 0.393336	valid_1's rmse: 0.450812
# [700]	training's rmse: 0.377467	valid_1's rmse: 0.4494
# [800]	training's rmse: 0.363034	valid_1's rmse: 0.448314
# [900]	training's rmse: 0.34967	valid_1's rmse: 0.447886
# [1000]	training's rmse: 0.33715	valid_1's rmse: 0.447568
# [1100]	training's rmse: 0.32537	valid_1's rmse: 0.447492
# [1200]	training's rmse: 0.314154	valid_1's rmse: 0.446995
# [1300]	training's rmse: 0.30388	valid_1's rmse: 0.44681
# [1400]	training's rmse: 0.294022	valid_1's rmse: 0.446954
# [1500]	training's rmse: 0.284805	valid_1's rmse: 0.446758
# [1600]	training's rmse: 0.275522	valid_1's rmse: 0.44658
# [1700]	training's rmse: 0.266818	valid_1's rmse: 0.446609
# [1800]	training's rmse: 0.25855	valid_1's rmse: 0.446826
# Early stopping, best iteration is:
# [1606]	training's rmse: 0.274992	valid_1's rmse: 0.446483
# Model training81.774[s]
# score: 0.44648
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.643883	valid_1's rmse: 0.661177
# [200]	training's rmse: 0.501264	valid_1's rmse: 0.534338
# [300]	training's rmse: 0.455344	valid_1's rmse: 0.506415
# [400]	training's rmse: 0.429218	valid_1's rmse: 0.49707
# [500]	training's rmse: 0.408789	valid_1's rmse: 0.49301
# [600]	training's rmse: 0.391263	valid_1's rmse: 0.490075
# [700]	training's rmse: 0.375468	valid_1's rmse: 0.489181
# [800]	training's rmse: 0.361203	valid_1's rmse: 0.488395
# [900]	training's rmse: 0.347892	valid_1's rmse: 0.487952
# [1000]	training's rmse: 0.33575	valid_1's rmse: 0.487666
# [1100]	training's rmse: 0.324277	valid_1's rmse: 0.487143
# [1200]	training's rmse: 0.313636	valid_1's rmse: 0.486573
# [1300]	training's rmse: 0.303155	valid_1's rmse: 0.486398
# [1400]	training's rmse: 0.293398	valid_1's rmse: 0.48608
# [1500]	training's rmse: 0.284085	valid_1's rmse: 0.485861
# [1600]	training's rmse: 0.275037	valid_1's rmse: 0.48608
# [1700]	training's rmse: 0.26641	valid_1's rmse: 0.48593
# Early stopping, best iteration is:
# [1512]	training's rmse: 0.282969	valid_1's rmse: 0.48577
# Model training77.918[s]
# score: 0.48577
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.641308	valid_1's rmse: 0.685909
# [200]	training's rmse: 0.497301	valid_1's rmse: 0.576171
# [300]	training's rmse: 0.451872	valid_1's rmse: 0.556598
# [400]	training's rmse: 0.426216	valid_1's rmse: 0.550605
# [500]	training's rmse: 0.406024	valid_1's rmse: 0.547111
# [600]	training's rmse: 0.388715	valid_1's rmse: 0.54613
# [700]	training's rmse: 0.373203	valid_1's rmse: 0.54501
# [800]	training's rmse: 0.358859	valid_1's rmse: 0.544513
# [900]	training's rmse: 0.345739	valid_1's rmse: 0.543937
# [1000]	training's rmse: 0.333641	valid_1's rmse: 0.543342
# [1100]	training's rmse: 0.322088	valid_1's rmse: 0.543303
# [1200]	training's rmse: 0.311334	valid_1's rmse: 0.542999
# [1300]	training's rmse: 0.300768	valid_1's rmse: 0.542871
# [1400]	training's rmse: 0.291424	valid_1's rmse: 0.54278
# [1500]	training's rmse: 0.282015	valid_1's rmse: 0.542853
# [1600]	training's rmse: 0.273177	valid_1's rmse: 0.542797
# Early stopping, best iteration is:
# [1426]	training's rmse: 0.288858	valid_1's rmse: 0.542511
# Model training74.479[s]
# score: 0.54251
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645351	valid_1's rmse: 0.652741
# [200]	training's rmse: 0.502851	valid_1's rmse: 0.524873
# [300]	training's rmse: 0.456982	valid_1's rmse: 0.495407
# [400]	training's rmse: 0.43125	valid_1's rmse: 0.485535
# [500]	training's rmse: 0.410859	valid_1's rmse: 0.480223
# [600]	training's rmse: 0.393037	valid_1's rmse: 0.477585
# [700]	training's rmse: 0.377199	valid_1's rmse: 0.476664
# [800]	training's rmse: 0.362677	valid_1's rmse: 0.476131
# [900]	training's rmse: 0.349232	valid_1's rmse: 0.475241
# [1000]	training's rmse: 0.336862	valid_1's rmse: 0.475108
# [1100]	training's rmse: 0.325381	valid_1's rmse: 0.475725
# Early stopping, best iteration is:
# [934]	training's rmse: 0.344963	valid_1's rmse: 0.474837
# Model training53.587[s]
# score: 0.47484
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644429	valid_1's rmse: 0.657195
# [200]	training's rmse: 0.501034	valid_1's rmse: 0.537037
# [300]	training's rmse: 0.455217	valid_1's rmse: 0.510928
# [400]	training's rmse: 0.429286	valid_1's rmse: 0.502219
# [500]	training's rmse: 0.40909	valid_1's rmse: 0.498029
# [600]	training's rmse: 0.391363	valid_1's rmse: 0.495586
# [700]	training's rmse: 0.375613	valid_1's rmse: 0.493948
# [800]	training's rmse: 0.361435	valid_1's rmse: 0.493768
# [900]	training's rmse: 0.348222	valid_1's rmse: 0.49302
# [1000]	training's rmse: 0.335999	valid_1's rmse: 0.492329
# [1100]	training's rmse: 0.324251	valid_1's rmse: 0.491551
# [1200]	training's rmse: 0.313192	valid_1's rmse: 0.490994
# [1300]	training's rmse: 0.302739	valid_1's rmse: 0.490147
# [1400]	training's rmse: 0.292956	valid_1's rmse: 0.489684
# [1500]	training's rmse: 0.283573	valid_1's rmse: 0.489943
# [1600]	training's rmse: 0.274601	valid_1's rmse: 0.490124
# Early stopping, best iteration is:
# [1404]	training's rmse: 0.292597	valid_1's rmse: 0.489622
# Model training73.724[s]
# score: 0.48962
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.642942	valid_1's rmse: 0.67107
# [200]	training's rmse: 0.499356	valid_1's rmse: 0.556204
# [300]	training's rmse: 0.453443	valid_1's rmse: 0.534713
# [400]	training's rmse: 0.427664	valid_1's rmse: 0.529112
# [500]	training's rmse: 0.40749	valid_1's rmse: 0.527219
# [600]	training's rmse: 0.390016	valid_1's rmse: 0.526955
# [700]	training's rmse: 0.374396	valid_1's rmse: 0.52732
# Early stopping, best iteration is:
# [537]	training's rmse: 0.400746	valid_1's rmse: 0.526754
# Model training36.667[s]
# score: 0.52675
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.643791	valid_1's rmse: 0.670291
# [200]	training's rmse: 0.500701	valid_1's rmse: 0.545016
# [300]	training's rmse: 0.45551	valid_1's rmse: 0.516139
# [400]	training's rmse: 0.429503	valid_1's rmse: 0.506195
# [500]	training's rmse: 0.409253	valid_1's rmse: 0.50151
# [600]	training's rmse: 0.391857	valid_1's rmse: 0.498886
# [700]	training's rmse: 0.376122	valid_1's rmse: 0.496347
# [800]	training's rmse: 0.361799	valid_1's rmse: 0.494731
# [900]	training's rmse: 0.348539	valid_1's rmse: 0.49359
# [1000]	training's rmse: 0.336177	valid_1's rmse: 0.49306
# [1100]	training's rmse: 0.324711	valid_1's rmse: 0.492418
# [1200]	training's rmse: 0.313902	valid_1's rmse: 0.49207
# [1300]	training's rmse: 0.303326	valid_1's rmse: 0.492382
# Early stopping, best iteration is:
# [1197]	training's rmse: 0.314224	valid_1's rmse: 0.492003
# Model training65.124[s]
# score: 0.49200
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644103	valid_1's rmse: 0.658231
# [200]	training's rmse: 0.501083	valid_1's rmse: 0.5342
# [300]	training's rmse: 0.455072	valid_1's rmse: 0.509444
# [400]	training's rmse: 0.429304	valid_1's rmse: 0.502244
# [500]	training's rmse: 0.40909	valid_1's rmse: 0.498348
# [600]	training's rmse: 0.391871	valid_1's rmse: 0.495859
# [700]	training's rmse: 0.376303	valid_1's rmse: 0.494113
# [800]	training's rmse: 0.362005	valid_1's rmse: 0.49273
# [900]	training's rmse: 0.348831	valid_1's rmse: 0.492198
# [1000]	training's rmse: 0.336184	valid_1's rmse: 0.491537
# [1100]	training's rmse: 0.324532	valid_1's rmse: 0.49125
# [1200]	training's rmse: 0.313415	valid_1's rmse: 0.490951
# [1300]	training's rmse: 0.302944	valid_1's rmse: 0.491077
# [1400]	training's rmse: 0.292828	valid_1's rmse: 0.491172
# Early stopping, best iteration is:
# [1217]	training's rmse: 0.311515	valid_1's rmse: 0.490709
# Model training66.494[s]
# score: 0.49071
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644089	valid_1's rmse: 0.663869
# [200]	training's rmse: 0.50071	valid_1's rmse: 0.54336
# [300]	training's rmse: 0.455106	valid_1's rmse: 0.517311
# [400]	training's rmse: 0.429134	valid_1's rmse: 0.507828
# [500]	training's rmse: 0.408675	valid_1's rmse: 0.503505
# [600]	training's rmse: 0.391001	valid_1's rmse: 0.500642
# [700]	training's rmse: 0.375067	valid_1's rmse: 0.500041
# [800]	training's rmse: 0.36078	valid_1's rmse: 0.49916
# [900]	training's rmse: 0.347537	valid_1's rmse: 0.497988
# [1000]	training's rmse: 0.335155	valid_1's rmse: 0.497066
# [1100]	training's rmse: 0.323654	valid_1's rmse: 0.497172
# [1200]	training's rmse: 0.312663	valid_1's rmse: 0.496869
# [1300]	training's rmse: 0.302295	valid_1's rmse: 0.497111
# [1400]	training's rmse: 0.292198	valid_1's rmse: 0.497001
# [1500]	training's rmse: 0.282661	valid_1's rmse: 0.496919
# Early stopping, best iteration is:
# [1350]	training's rmse: 0.297202	valid_1's rmse: 0.496805
# Model training71.925[s]
# score: 0.49681
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.643571	valid_1's rmse: 0.670269
# [200]	training's rmse: 0.499835	valid_1's rmse: 0.548773
# [300]	training's rmse: 0.454124	valid_1's rmse: 0.521175
# [400]	training's rmse: 0.42864	valid_1's rmse: 0.51129
# [500]	training's rmse: 0.408494	valid_1's rmse: 0.506733
# [600]	training's rmse: 0.391005	valid_1's rmse: 0.503905
# [700]	training's rmse: 0.375249	valid_1's rmse: 0.502755
# [800]	training's rmse: 0.360889	valid_1's rmse: 0.501575
# [900]	training's rmse: 0.347696	valid_1's rmse: 0.50059
# [1000]	training's rmse: 0.335347	valid_1's rmse: 0.500407
# [1100]	training's rmse: 0.323793	valid_1's rmse: 0.499631
# [1200]	training's rmse: 0.3129	valid_1's rmse: 0.499459
# [1300]	training's rmse: 0.302869	valid_1's rmse: 0.499024
# [1400]	training's rmse: 0.293075	valid_1's rmse: 0.498799
# [1500]	training's rmse: 0.283807	valid_1's rmse: 0.498469
# [1600]	training's rmse: 0.274549	valid_1's rmse: 0.498133
# [1700]	training's rmse: 0.266135	valid_1's rmse: 0.497913
# [1800]	training's rmse: 0.257963	valid_1's rmse: 0.497503
# [1900]	training's rmse: 0.250067	valid_1's rmse: 0.497769
# [2000]	training's rmse: 0.242227	valid_1's rmse: 0.497433
# [2100]	training's rmse: 0.234695	valid_1's rmse: 0.49722
# [2200]	training's rmse: 0.227661	valid_1's rmse: 0.497211
# [2300]	training's rmse: 0.220687	valid_1's rmse: 0.497077
# [2400]	training's rmse: 0.214153	valid_1's rmse: 0.496668
# [2500]	training's rmse: 0.207756	valid_1's rmse: 0.496807
# [2600]	training's rmse: 0.201599	valid_1's rmse: 0.496796
# [2700]	training's rmse: 0.195828	valid_1's rmse: 0.496644
# [2800]	training's rmse: 0.190104	valid_1's rmse: 0.496968
# [2900]	training's rmse: 0.184412	valid_1's rmse: 0.496769
# Early stopping, best iteration is:
# [2727]	training's rmse: 0.194288	valid_1's rmse: 0.496581
# Model training96.374[s]
# score: 0.49658
# oof score:  0.487853
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.643995	valid_1's rmse: 0.674515
# [200]	training's rmse: 0.500516	valid_1's rmse: 0.551417
# [300]	training's rmse: 0.454921	valid_1's rmse: 0.522714
# [400]	training's rmse: 0.429009	valid_1's rmse: 0.513532
# [500]	training's rmse: 0.408749	valid_1's rmse: 0.509813
# [600]	training's rmse: 0.391111	valid_1's rmse: 0.5085
# [700]	training's rmse: 0.375601	valid_1's rmse: 0.506154
# [800]	training's rmse: 0.361389	valid_1's rmse: 0.505063
# [900]	training's rmse: 0.348162	valid_1's rmse: 0.504164
# [1000]	training's rmse: 0.335896	valid_1's rmse: 0.503204
# [1100]	training's rmse: 0.324248	valid_1's rmse: 0.502359
# [1200]	training's rmse: 0.313392	valid_1's rmse: 0.501823
# [1300]	training's rmse: 0.302947	valid_1's rmse: 0.501842
# [1400]	training's rmse: 0.293007	valid_1's rmse: 0.501824
# [1500]	training's rmse: 0.283534	valid_1's rmse: 0.501692
# [1600]	training's rmse: 0.274428	valid_1's rmse: 0.500947
# [1700]	training's rmse: 0.266051	valid_1's rmse: 0.50097
# [1800]	training's rmse: 0.25768	valid_1's rmse: 0.500515
# [1900]	training's rmse: 0.249793	valid_1's rmse: 0.500864
# Early stopping, best iteration is:
# [1753]	training's rmse: 0.261535	valid_1's rmse: 0.500452
# Model training88.129[s]
# score: 0.50045
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644987	valid_1's rmse: 0.646025
# [200]	training's rmse: 0.502293	valid_1's rmse: 0.517771
# [300]	training's rmse: 0.456631	valid_1's rmse: 0.488489
# [400]	training's rmse: 0.430651	valid_1's rmse: 0.478217
# [500]	training's rmse: 0.41046	valid_1's rmse: 0.473298
# [600]	training's rmse: 0.392784	valid_1's rmse: 0.470439
# [700]	training's rmse: 0.37686	valid_1's rmse: 0.469249
# [800]	training's rmse: 0.362543	valid_1's rmse: 0.467891
# [900]	training's rmse: 0.349157	valid_1's rmse: 0.467597
# [1000]	training's rmse: 0.336881	valid_1's rmse: 0.466927
# [1100]	training's rmse: 0.325305	valid_1's rmse: 0.46668
# [1200]	training's rmse: 0.314271	valid_1's rmse: 0.466713
# [1300]	training's rmse: 0.303957	valid_1's rmse: 0.466509
# [1400]	training's rmse: 0.294067	valid_1's rmse: 0.4666
# [1500]	training's rmse: 0.284833	valid_1's rmse: 0.466383
# [1600]	training's rmse: 0.275681	valid_1's rmse: 0.466374
# Early stopping, best iteration is:
# [1466]	training's rmse: 0.287942	valid_1's rmse: 0.466171
# Model training76.055[s]
# score: 0.46617
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.643909	valid_1's rmse: 0.6506
# [200]	training's rmse: 0.501592	valid_1's rmse: 0.527519
# [300]	training's rmse: 0.456339	valid_1's rmse: 0.500908
# [400]	training's rmse: 0.430823	valid_1's rmse: 0.492788
# [500]	training's rmse: 0.410348	valid_1's rmse: 0.488655
# [600]	training's rmse: 0.392798	valid_1's rmse: 0.487091
# [700]	training's rmse: 0.377074	valid_1's rmse: 0.486401
# [800]	training's rmse: 0.362778	valid_1's rmse: 0.48532
# [900]	training's rmse: 0.34948	valid_1's rmse: 0.484889
# [1000]	training's rmse: 0.337034	valid_1's rmse: 0.48388
# [1100]	training's rmse: 0.325456	valid_1's rmse: 0.483441
# [1200]	training's rmse: 0.314511	valid_1's rmse: 0.48326
# [1300]	training's rmse: 0.30393	valid_1's rmse: 0.483522
# Early stopping, best iteration is:
# [1190]	training's rmse: 0.315627	valid_1's rmse: 0.483189
# Model training64.793[s]
# score: 0.48319
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644974	valid_1's rmse: 0.64933
# [200]	training's rmse: 0.502203	valid_1's rmse: 0.523688
# [300]	training's rmse: 0.456059	valid_1's rmse: 0.49799
# [400]	training's rmse: 0.430173	valid_1's rmse: 0.492411
# [500]	training's rmse: 0.409663	valid_1's rmse: 0.489817
# [600]	training's rmse: 0.391969	valid_1's rmse: 0.488247
# [700]	training's rmse: 0.376398	valid_1's rmse: 0.488004
# [800]	training's rmse: 0.361892	valid_1's rmse: 0.487298
# [900]	training's rmse: 0.348722	valid_1's rmse: 0.487364
# [1000]	training's rmse: 0.336488	valid_1's rmse: 0.487114
# [1100]	training's rmse: 0.324851	valid_1's rmse: 0.487548
# Early stopping, best iteration is:
# [990]	training's rmse: 0.337642	valid_1's rmse: 0.486984
# Model training56.348[s]
# score: 0.48698
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.643771	valid_1's rmse: 0.666858
# [200]	training's rmse: 0.500451	valid_1's rmse: 0.545922
# [300]	training's rmse: 0.454863	valid_1's rmse: 0.521322
# [400]	training's rmse: 0.429142	valid_1's rmse: 0.512844
# [500]	training's rmse: 0.408765	valid_1's rmse: 0.509125
# [600]	training's rmse: 0.391031	valid_1's rmse: 0.506395
# [700]	training's rmse: 0.375332	valid_1's rmse: 0.504739
# [800]	training's rmse: 0.360988	valid_1's rmse: 0.503519
# [900]	training's rmse: 0.347536	valid_1's rmse: 0.503475
# [1000]	training's rmse: 0.335045	valid_1's rmse: 0.502949
# [1100]	training's rmse: 0.3237	valid_1's rmse: 0.502923
# [1200]	training's rmse: 0.312818	valid_1's rmse: 0.50311
# Early stopping, best iteration is:
# [1024]	training's rmse: 0.332238	valid_1's rmse: 0.50278
# Model training57.482[s]
# score: 0.50278
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645631	valid_1's rmse: 0.642768
# [200]	training's rmse: 0.502835	valid_1's rmse: 0.509025
# [300]	training's rmse: 0.456913	valid_1's rmse: 0.478297
# [400]	training's rmse: 0.430821	valid_1's rmse: 0.467779
# [500]	training's rmse: 0.41072	valid_1's rmse: 0.463723
# [600]	training's rmse: 0.39346	valid_1's rmse: 0.462335
# [700]	training's rmse: 0.377746	valid_1's rmse: 0.461122
# [800]	training's rmse: 0.363378	valid_1's rmse: 0.460752
# [900]	training's rmse: 0.350156	valid_1's rmse: 0.459672
# [1000]	training's rmse: 0.337682	valid_1's rmse: 0.459451
# [1100]	training's rmse: 0.32615	valid_1's rmse: 0.45929
# [1200]	training's rmse: 0.315202	valid_1's rmse: 0.459
# [1300]	training's rmse: 0.304631	valid_1's rmse: 0.458657
# [1400]	training's rmse: 0.294622	valid_1's rmse: 0.458637
# [1500]	training's rmse: 0.285086	valid_1's rmse: 0.45915
# Early stopping, best iteration is:
# [1392]	training's rmse: 0.295438	valid_1's rmse: 0.458569
# Model training73.214[s]
# score: 0.45857
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644435	valid_1's rmse: 0.663736
# [200]	training's rmse: 0.500953	valid_1's rmse: 0.544404
# [300]	training's rmse: 0.454908	valid_1's rmse: 0.517917
# [400]	training's rmse: 0.428966	valid_1's rmse: 0.509347
# [500]	training's rmse: 0.408678	valid_1's rmse: 0.505448
# [600]	training's rmse: 0.3909	valid_1's rmse: 0.502647
# [700]	training's rmse: 0.375063	valid_1's rmse: 0.500595
# [800]	training's rmse: 0.360587	valid_1's rmse: 0.499372
# [900]	training's rmse: 0.34748	valid_1's rmse: 0.499028
# [1000]	training's rmse: 0.335168	valid_1's rmse: 0.498906
# [1100]	training's rmse: 0.323912	valid_1's rmse: 0.497907
# [1200]	training's rmse: 0.313096	valid_1's rmse: 0.497672
# [1300]	training's rmse: 0.302831	valid_1's rmse: 0.49759
# [1400]	training's rmse: 0.293026	valid_1's rmse: 0.497524
# [1500]	training's rmse: 0.283466	valid_1's rmse: 0.497501
# Early stopping, best iteration is:
# [1396]	training's rmse: 0.293413	valid_1's rmse: 0.497425
# Model training73.139[s]
# score: 0.49743
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645962	valid_1's rmse: 0.64526
# [200]	training's rmse: 0.503276	valid_1's rmse: 0.510121
# [300]	training's rmse: 0.457373	valid_1's rmse: 0.479633
# [400]	training's rmse: 0.430937	valid_1's rmse: 0.469982
# [500]	training's rmse: 0.410493	valid_1's rmse: 0.465953
# [600]	training's rmse: 0.392884	valid_1's rmse: 0.463349
# [700]	training's rmse: 0.377078	valid_1's rmse: 0.461779
# [800]	training's rmse: 0.362663	valid_1's rmse: 0.461806
# [900]	training's rmse: 0.349366	valid_1's rmse: 0.461234
# [1000]	training's rmse: 0.336677	valid_1's rmse: 0.461057
# [1100]	training's rmse: 0.325224	valid_1's rmse: 0.460598
# [1200]	training's rmse: 0.314055	valid_1's rmse: 0.460678
# [1300]	training's rmse: 0.30363	valid_1's rmse: 0.460782
# Early stopping, best iteration is:
# [1170]	training's rmse: 0.317314	valid_1's rmse: 0.460448
# Model training63.726[s]
# score: 0.46045
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645054	valid_1's rmse: 0.660996
# [200]	training's rmse: 0.501234	valid_1's rmse: 0.541401
# [300]	training's rmse: 0.455206	valid_1's rmse: 0.517051
# [400]	training's rmse: 0.429418	valid_1's rmse: 0.508195
# [500]	training's rmse: 0.40914	valid_1's rmse: 0.503194
# [600]	training's rmse: 0.391764	valid_1's rmse: 0.499843
# [700]	training's rmse: 0.375971	valid_1's rmse: 0.497924
# [800]	training's rmse: 0.36166	valid_1's rmse: 0.496941
# [900]	training's rmse: 0.348447	valid_1's rmse: 0.495707
# [1000]	training's rmse: 0.33619	valid_1's rmse: 0.495279
# [1100]	training's rmse: 0.324633	valid_1's rmse: 0.494918
# [1200]	training's rmse: 0.313556	valid_1's rmse: 0.495043
# [1300]	training's rmse: 0.302954	valid_1's rmse: 0.494652
# [1400]	training's rmse: 0.292987	valid_1's rmse: 0.494689
# [1500]	training's rmse: 0.283675	valid_1's rmse: 0.494021
# [1600]	training's rmse: 0.274912	valid_1's rmse: 0.493883
# [1700]	training's rmse: 0.266324	valid_1's rmse: 0.493739
# [1800]	training's rmse: 0.258302	valid_1's rmse: 0.493933
# [1900]	training's rmse: 0.250332	valid_1's rmse: 0.493813
# [2000]	training's rmse: 0.242646	valid_1's rmse: 0.493743
# [2100]	training's rmse: 0.235271	valid_1's rmse: 0.493668
# Early stopping, best iteration is:
# [1958]	training's rmse: 0.245823	valid_1's rmse: 0.493505
# Model training72.304[s]
# score: 0.49351
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.643893	valid_1's rmse: 0.66426
# [200]	training's rmse: 0.499811	valid_1's rmse: 0.544861
# [300]	training's rmse: 0.454052	valid_1's rmse: 0.519054
# [400]	training's rmse: 0.428087	valid_1's rmse: 0.511203
# [500]	training's rmse: 0.407923	valid_1's rmse: 0.507874
# [600]	training's rmse: 0.390552	valid_1's rmse: 0.505099
# [700]	training's rmse: 0.374908	valid_1's rmse: 0.503892
# [800]	training's rmse: 0.360637	valid_1's rmse: 0.502361
# [900]	training's rmse: 0.34737	valid_1's rmse: 0.501795
# [1000]	training's rmse: 0.335023	valid_1's rmse: 0.501144
# [1100]	training's rmse: 0.323284	valid_1's rmse: 0.500654
# [1200]	training's rmse: 0.31241	valid_1's rmse: 0.500728
# [1300]	training's rmse: 0.302199	valid_1's rmse: 0.500596
# Early stopping, best iteration is:
# [1165]	training's rmse: 0.316088	valid_1's rmse: 0.500182
# Model training63.474[s]
# score: 0.50018
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645308	valid_1's rmse: 0.655065
# [200]	training's rmse: 0.501811	valid_1's rmse: 0.529154
# [300]	training's rmse: 0.45563	valid_1's rmse: 0.501793
# [400]	training's rmse: 0.429584	valid_1's rmse: 0.494574
# [500]	training's rmse: 0.40919	valid_1's rmse: 0.491041
# [600]	training's rmse: 0.391667	valid_1's rmse: 0.489853
# [700]	training's rmse: 0.375864	valid_1's rmse: 0.489101
# [800]	training's rmse: 0.361504	valid_1's rmse: 0.488962
# [900]	training's rmse: 0.348285	valid_1's rmse: 0.488517
# [1000]	training's rmse: 0.335978	valid_1's rmse: 0.487917
# [1100]	training's rmse: 0.324216	valid_1's rmse: 0.48772
# [1200]	training's rmse: 0.313473	valid_1's rmse: 0.487418
# [1300]	training's rmse: 0.302989	valid_1's rmse: 0.486954
# [1400]	training's rmse: 0.293285	valid_1's rmse: 0.486856
# [1500]	training's rmse: 0.283817	valid_1's rmse: 0.486807
# [1600]	training's rmse: 0.274678	valid_1's rmse: 0.486961
# [1700]	training's rmse: 0.266016	valid_1's rmse: 0.486842
# Early stopping, best iteration is:
# [1525]	training's rmse: 0.28141	valid_1's rmse: 0.486554
# Model training78.885[s]
# score: 0.48655
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.643241	valid_1's rmse: 0.674887
# [200]	training's rmse: 0.499845	valid_1's rmse: 0.554153
# [300]	training's rmse: 0.453453	valid_1's rmse: 0.529313
# [400]	training's rmse: 0.427619	valid_1's rmse: 0.521835
# [500]	training's rmse: 0.407202	valid_1's rmse: 0.519169
# [600]	training's rmse: 0.389909	valid_1's rmse: 0.517659
# [700]	training's rmse: 0.37429	valid_1's rmse: 0.517017
# [800]	training's rmse: 0.359702	valid_1's rmse: 0.516694
# [900]	training's rmse: 0.346483	valid_1's rmse: 0.516663
# [1000]	training's rmse: 0.334049	valid_1's rmse: 0.516447
# [1100]	training's rmse: 0.322439	valid_1's rmse: 0.515803
# [1200]	training's rmse: 0.311648	valid_1's rmse: 0.515722
# Early stopping, best iteration is:
# [1061]	training's rmse: 0.326855	valid_1's rmse: 0.515624
# Model training59.265[s]
# score: 0.51562
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.646547	valid_1's rmse: 0.646576
# [200]	training's rmse: 0.503255	valid_1's rmse: 0.506077
# [300]	training's rmse: 0.457525	valid_1's rmse: 0.473038
# [400]	training's rmse: 0.431289	valid_1's rmse: 0.462326
# [500]	training's rmse: 0.410591	valid_1's rmse: 0.458381
# [600]	training's rmse: 0.393163	valid_1's rmse: 0.45602
# [700]	training's rmse: 0.377342	valid_1's rmse: 0.455263
# [800]	training's rmse: 0.362743	valid_1's rmse: 0.454487
# [900]	training's rmse: 0.349677	valid_1's rmse: 0.454644
# Early stopping, best iteration is:
# [746]	training's rmse: 0.370501	valid_1's rmse: 0.45442
# Model training35.103[s]
# score: 0.45442
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645018	valid_1's rmse: 0.65377
# [200]	training's rmse: 0.501496	valid_1's rmse: 0.535481
# [300]	training's rmse: 0.455565	valid_1's rmse: 0.511002
# [400]	training's rmse: 0.429232	valid_1's rmse: 0.504093
# [500]	training's rmse: 0.408493	valid_1's rmse: 0.500962
# [600]	training's rmse: 0.391017	valid_1's rmse: 0.499509
# [700]	training's rmse: 0.375047	valid_1's rmse: 0.497956
# [800]	training's rmse: 0.360783	valid_1's rmse: 0.497027
# [900]	training's rmse: 0.347466	valid_1's rmse: 0.496322
# [1000]	training's rmse: 0.335343	valid_1's rmse: 0.49528
# [1100]	training's rmse: 0.323624	valid_1's rmse: 0.49552
# [1200]	training's rmse: 0.312598	valid_1's rmse: 0.495244
# [1300]	training's rmse: 0.30229	valid_1's rmse: 0.494817
# [1400]	training's rmse: 0.292435	valid_1's rmse: 0.495279
# Early stopping, best iteration is:
# [1266]	training's rmse: 0.305837	valid_1's rmse: 0.494754
# Model training68.155[s]
# score: 0.49475
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.64359	valid_1's rmse: 0.667005
# [200]	training's rmse: 0.500133	valid_1's rmse: 0.550756
# [300]	training's rmse: 0.454021	valid_1's rmse: 0.525381
# [400]	training's rmse: 0.428068	valid_1's rmse: 0.517566
# [500]	training's rmse: 0.407676	valid_1's rmse: 0.513163
# [600]	training's rmse: 0.390023	valid_1's rmse: 0.511208
# [700]	training's rmse: 0.3744	valid_1's rmse: 0.50992
# [800]	training's rmse: 0.360183	valid_1's rmse: 0.509423
# [900]	training's rmse: 0.347055	valid_1's rmse: 0.508587
# [1000]	training's rmse: 0.334776	valid_1's rmse: 0.508631
# [1100]	training's rmse: 0.323124	valid_1's rmse: 0.508527
# [1200]	training's rmse: 0.312169	valid_1's rmse: 0.508557
# [1300]	training's rmse: 0.301912	valid_1's rmse: 0.508382
# [1400]	training's rmse: 0.292142	valid_1's rmse: 0.508441
# [1500]	training's rmse: 0.282999	valid_1's rmse: 0.508289
# [1600]	training's rmse: 0.273864	valid_1's rmse: 0.508467
# Early stopping, best iteration is:
# [1452]	training's rmse: 0.287266	valid_1's rmse: 0.508103
# Model training75.741[s]
# score: 0.50810
# oof score:  0.487627
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644417	valid_1's rmse: 0.663807
# [200]	training's rmse: 0.500122	valid_1's rmse: 0.543723
# [300]	training's rmse: 0.454337	valid_1's rmse: 0.515745
# [400]	training's rmse: 0.428354	valid_1's rmse: 0.506452
# [500]	training's rmse: 0.407973	valid_1's rmse: 0.501948
# [600]	training's rmse: 0.390591	valid_1's rmse: 0.499266
# [700]	training's rmse: 0.375024	valid_1's rmse: 0.498516
# [800]	training's rmse: 0.360601	valid_1's rmse: 0.497973
# [900]	training's rmse: 0.347537	valid_1's rmse: 0.497687
# [1000]	training's rmse: 0.33497	valid_1's rmse: 0.497865
# [1100]	training's rmse: 0.323112	valid_1's rmse: 0.49749
# [1200]	training's rmse: 0.311914	valid_1's rmse: 0.497215
# [1300]	training's rmse: 0.301351	valid_1's rmse: 0.497642
# Early stopping, best iteration is:
# [1198]	training's rmse: 0.312132	valid_1's rmse: 0.497159
# Model training64.987[s]
# ...
# [100]	training's rmse: 0.645571	valid_1's rmse: 0.647873
# [200]	training's rmse: 0.502629	valid_1's rmse: 0.514565
# [300]	training's rmse: 0.457149	valid_1's rmse: 0.483137
# [400]	training's rmse: 0.431026	valid_1's rmse: 0.471438
# [500]	training's rmse: 0.410573	valid_1's rmse: 0.468133
# [600]	training's rmse: 0.392788	valid_1's rmse: 0.466209
# [700]	training's rmse: 0.376991	valid_1's rmse: 0.464602
# [800]	training's rmse: 0.362592	valid_1's rmse: 0.464159
# [900]	training's rmse: 0.349356	valid_1's rmse: 0.464313
# [1000]	training's rmse: 0.337165	valid_1's rmse: 0.463838
# [1100]	training's rmse: 0.32542	valid_1's rmse: 0.463964
# [1200]	training's rmse: 0.314361	valid_1's rmse: 0.464258
# Early stopping, best iteration is:
# [1020]	training's rmse: 0.334656	valid_1's rmse: 0.463699
# Model training57.418[s]
# score: 0.46370
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.643935	valid_1's rmse: 0.665345
# [200]	training's rmse: 0.501048	valid_1's rmse: 0.539638
# [300]	training's rmse: 0.455635	valid_1's rmse: 0.509254
# [400]	training's rmse: 0.429883	valid_1's rmse: 0.497921
# [500]	training's rmse: 0.409575	valid_1's rmse: 0.492263
# [600]	training's rmse: 0.3922	valid_1's rmse: 0.489196
# [700]	training's rmse: 0.376363	valid_1's rmse: 0.48687
# [800]	training's rmse: 0.361806	valid_1's rmse: 0.485841
# [900]	training's rmse: 0.348522	valid_1's rmse: 0.48576
# [1000]	training's rmse: 0.336083	valid_1's rmse: 0.485635
# [1100]	training's rmse: 0.324295	valid_1's rmse: 0.485195
# [1200]	training's rmse: 0.313124	valid_1's rmse: 0.484844
# [1300]	training's rmse: 0.302822	valid_1's rmse: 0.484584
# [1400]	training's rmse: 0.293128	valid_1's rmse: 0.484439
# [1500]	training's rmse: 0.283534	valid_1's rmse: 0.484305
# [1600]	training's rmse: 0.27438	valid_1's rmse: 0.484728
# Early stopping, best iteration is:
# [1479]	training's rmse: 0.285528	valid_1's rmse: 0.484005
# Model training57.621[s]
# score: 0.48401
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645396	valid_1's rmse: 0.649179
# [200]	training's rmse: 0.502183	valid_1's rmse: 0.524705
# [300]	training's rmse: 0.456535	valid_1's rmse: 0.496842
# [400]	training's rmse: 0.430532	valid_1's rmse: 0.48755
# [500]	training's rmse: 0.410248	valid_1's rmse: 0.483066
# [600]	training's rmse: 0.392691	valid_1's rmse: 0.480339
# [700]	training's rmse: 0.377142	valid_1's rmse: 0.478103
# [800]	training's rmse: 0.362669	valid_1's rmse: 0.476519
# [900]	training's rmse: 0.349338	valid_1's rmse: 0.475598
# [1000]	training's rmse: 0.336689	valid_1's rmse: 0.474505
# [1100]	training's rmse: 0.324917	valid_1's rmse: 0.473515
# [1200]	training's rmse: 0.314125	valid_1's rmse: 0.472861
# [1300]	training's rmse: 0.303778	valid_1's rmse: 0.472365
# [1400]	training's rmse: 0.293937	valid_1's rmse: 0.472393
# [1500]	training's rmse: 0.284534	valid_1's rmse: 0.472075
# [1600]	training's rmse: 0.275425	valid_1's rmse: 0.472166
# [1700]	training's rmse: 0.266736	valid_1's rmse: 0.472001
# [1800]	training's rmse: 0.258429	valid_1's rmse: 0.471686
# [1900]	training's rmse: 0.250593	valid_1's rmse: 0.471549
# [2000]	training's rmse: 0.242732	valid_1's rmse: 0.471463
# Early stopping, best iteration is:
# [1848]	training's rmse: 0.254616	valid_1's rmse: 0.471361
# Model training91.813[s]
# score: 0.47136
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645437	valid_1's rmse: 0.655571
# [200]	training's rmse: 0.502732	valid_1's rmse: 0.514591
# [300]	training's rmse: 0.456666	valid_1's rmse: 0.480816
# [400]	training's rmse: 0.430628	valid_1's rmse: 0.470859
# [500]	training's rmse: 0.410337	valid_1's rmse: 0.466436
# [600]	training's rmse: 0.392528	valid_1's rmse: 0.463672
# [700]	training's rmse: 0.376696	valid_1's rmse: 0.461593
# [800]	training's rmse: 0.362459	valid_1's rmse: 0.460846
# [900]	training's rmse: 0.349055	valid_1's rmse: 0.459971
# [1000]	training's rmse: 0.336454	valid_1's rmse: 0.459968
# [1100]	training's rmse: 0.324659	valid_1's rmse: 0.459839
# [1200]	training's rmse: 0.313729	valid_1's rmse: 0.460123
# Early stopping, best iteration is:
# [1045]	training's rmse: 0.330998	valid_1's rmse: 0.45966
# Model training58.474[s]
# score: 0.45966
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.646655	valid_1's rmse: 0.642564
# [200]	training's rmse: 0.503069	valid_1's rmse: 0.514782
# [300]	training's rmse: 0.456823	valid_1's rmse: 0.485156
# [400]	training's rmse: 0.430808	valid_1's rmse: 0.476934
# [500]	training's rmse: 0.410526	valid_1's rmse: 0.473622
# [600]	training's rmse: 0.392834	valid_1's rmse: 0.472225
# [700]	training's rmse: 0.377098	valid_1's rmse: 0.471387
# [800]	training's rmse: 0.362965	valid_1's rmse: 0.470659
# [900]	training's rmse: 0.349621	valid_1's rmse: 0.470165
# [1000]	training's rmse: 0.337331	valid_1's rmse: 0.470017
# [1100]	training's rmse: 0.325758	valid_1's rmse: 0.469231
# [1200]	training's rmse: 0.314758	valid_1's rmse: 0.468755
# [1300]	training's rmse: 0.304238	valid_1's rmse: 0.468359
# [1400]	training's rmse: 0.294469	valid_1's rmse: 0.468473
# Early stopping, best iteration is:
# [1284]	training's rmse: 0.30595	valid_1's rmse: 0.468244
# Model training51.388[s]
# score: 0.46824
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645797	valid_1's rmse: 0.64565
# [200]	training's rmse: 0.502945	valid_1's rmse: 0.514579
# [300]	training's rmse: 0.457291	valid_1's rmse: 0.483819
# [400]	training's rmse: 0.431333	valid_1's rmse: 0.474197
# [500]	training's rmse: 0.410723	valid_1's rmse: 0.469156
# [600]	training's rmse: 0.393035	valid_1's rmse: 0.465979
# [700]	training's rmse: 0.377376	valid_1's rmse: 0.463285
# [800]	training's rmse: 0.363123	valid_1's rmse: 0.461759
# [900]	training's rmse: 0.349722	valid_1's rmse: 0.460661
# [1000]	training's rmse: 0.337314	valid_1's rmse: 0.459103
# [1100]	training's rmse: 0.325826	valid_1's rmse: 0.459212
# [1200]	training's rmse: 0.314873	valid_1's rmse: 0.458744
# [1300]	training's rmse: 0.30421	valid_1's rmse: 0.458271
# [1400]	training's rmse: 0.294469	valid_1's rmse: 0.458216
# [1500]	training's rmse: 0.285234	valid_1's rmse: 0.457845
# [1600]	training's rmse: 0.276226	valid_1's rmse: 0.457527
# [1700]	training's rmse: 0.267423	valid_1's rmse: 0.457517
# [1800]	training's rmse: 0.259146	valid_1's rmse: 0.457451
# [1900]	training's rmse: 0.251352	valid_1's rmse: 0.457466
# [2000]	training's rmse: 0.243737	valid_1's rmse: 0.45692
# [2100]	training's rmse: 0.236371	valid_1's rmse: 0.45662
# [2200]	training's rmse: 0.22921	valid_1's rmse: 0.456713
# [2300]	training's rmse: 0.22218	valid_1's rmse: 0.456853
# Early stopping, best iteration is:
# [2173]	training's rmse: 0.231114	valid_1's rmse: 0.456568
# Model training104.558[s]
# score: 0.45657
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.642318	valid_1's rmse: 0.66619
# [200]	training's rmse: 0.498591	valid_1's rmse: 0.560667
# [300]	training's rmse: 0.453066	valid_1's rmse: 0.543241
# [400]	training's rmse: 0.427016	valid_1's rmse: 0.540545
# [500]	training's rmse: 0.406829	valid_1's rmse: 0.538564
# [600]	training's rmse: 0.389449	valid_1's rmse: 0.53755
# [700]	training's rmse: 0.373553	valid_1's rmse: 0.537002
# [800]	training's rmse: 0.359399	valid_1's rmse: 0.536893
# [900]	training's rmse: 0.345929	valid_1's rmse: 0.536526
# [1000]	training's rmse: 0.333821	valid_1's rmse: 0.536431
# [1100]	training's rmse: 0.322239	valid_1's rmse: 0.536684
# Early stopping, best iteration is:
# [939]	training's rmse: 0.341225	valid_1's rmse: 0.53627
# Model training40.927[s]
# score: 0.53627
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644672	valid_1's rmse: 0.6506
# [200]	training's rmse: 0.501713	valid_1's rmse: 0.529028
# [300]	training's rmse: 0.455885	valid_1's rmse: 0.505593
# [400]	training's rmse: 0.429572	valid_1's rmse: 0.49818
# [500]	training's rmse: 0.409045	valid_1's rmse: 0.495089
# [600]	training's rmse: 0.391126	valid_1's rmse: 0.494588
# [700]	training's rmse: 0.375512	valid_1's rmse: 0.494461
# [800]	training's rmse: 0.361151	valid_1's rmse: 0.494443
# [900]	training's rmse: 0.347485	valid_1's rmse: 0.493985
# [1000]	training's rmse: 0.335158	valid_1's rmse: 0.493861
# [1100]	training's rmse: 0.323589	valid_1's rmse: 0.494305
# Early stopping, best iteration is:
# [965]	training's rmse: 0.339289	valid_1's rmse: 0.493591
# Model training54.923[s]
# score: 0.49359
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.641882	valid_1's rmse: 0.680302
# [200]	training's rmse: 0.498386	valid_1's rmse: 0.572707
# [300]	training's rmse: 0.452967	valid_1's rmse: 0.552392
# [400]	training's rmse: 0.427423	valid_1's rmse: 0.545601
# [500]	training's rmse: 0.407223	valid_1's rmse: 0.541879
# [600]	training's rmse: 0.389805	valid_1's rmse: 0.539365
# [700]	training's rmse: 0.374298	valid_1's rmse: 0.538076
# [800]	training's rmse: 0.360183	valid_1's rmse: 0.537399
# [900]	training's rmse: 0.346865	valid_1's rmse: 0.535817
# [1000]	training's rmse: 0.334656	valid_1's rmse: 0.535615
# [1100]	training's rmse: 0.323116	valid_1's rmse: 0.535186
# [1200]	training's rmse: 0.312141	valid_1's rmse: 0.535103
# [1300]	training's rmse: 0.301812	valid_1's rmse: 0.53463
# [1400]	training's rmse: 0.292216	valid_1's rmse: 0.534321
# [1500]	training's rmse: 0.282635	valid_1's rmse: 0.534425
# [1600]	training's rmse: 0.273616	valid_1's rmse: 0.53417
# [1700]	training's rmse: 0.264961	valid_1's rmse: 0.533795
# [1800]	training's rmse: 0.256748	valid_1's rmse: 0.533807
# [1900]	training's rmse: 0.248984	valid_1's rmse: 0.533728
# [2000]	training's rmse: 0.24128	valid_1's rmse: 0.53367
# [2100]	training's rmse: 0.233913	valid_1's rmse: 0.533438
# [2200]	training's rmse: 0.226742	valid_1's rmse: 0.533443
# [2300]	training's rmse: 0.219729	valid_1's rmse: 0.533489
# Early stopping, best iteration is:
# [2134]	training's rmse: 0.231474	valid_1's rmse: 0.533366
# Model training103.514[s]
# score: 0.53337
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645725	valid_1's rmse: 0.642662
# [200]	training's rmse: 0.502587	valid_1's rmse: 0.51431
# [300]	training's rmse: 0.456603	valid_1's rmse: 0.487109
# [400]	training's rmse: 0.43066	valid_1's rmse: 0.480188
# [500]	training's rmse: 0.410388	valid_1's rmse: 0.475536
# [600]	training's rmse: 0.39274	valid_1's rmse: 0.473328
# [700]	training's rmse: 0.376908	valid_1's rmse: 0.472052
# [800]	training's rmse: 0.362382	valid_1's rmse: 0.4713
# [900]	training's rmse: 0.349057	valid_1's rmse: 0.471091
# [1000]	training's rmse: 0.336773	valid_1's rmse: 0.471296
# Early stopping, best iteration is:
# [835]	training's rmse: 0.357418	valid_1's rmse: 0.470909
# Model training49.443[s]
# score: 0.47091
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644987	valid_1's rmse: 0.640118
# [200]	training's rmse: 0.5023	valid_1's rmse: 0.512645
# [300]	training's rmse: 0.456742	valid_1's rmse: 0.485289
# [400]	training's rmse: 0.430505	valid_1's rmse: 0.477345
# [500]	training's rmse: 0.410136	valid_1's rmse: 0.47418
# [600]	training's rmse: 0.392526	valid_1's rmse: 0.472402
# [700]	training's rmse: 0.376873	valid_1's rmse: 0.471394
# [800]	training's rmse: 0.362503	valid_1's rmse: 0.470692
# [900]	training's rmse: 0.349183	valid_1's rmse: 0.470137
# [1000]	training's rmse: 0.336888	valid_1's rmse: 0.469539
# [1100]	training's rmse: 0.325294	valid_1's rmse: 0.469414
# [1200]	training's rmse: 0.314031	valid_1's rmse: 0.469703
# Early stopping, best iteration is:
# [1096]	training's rmse: 0.325761	valid_1's rmse: 0.469377
# Model training45.350[s]
# score: 0.46938
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644563	valid_1's rmse: 0.659912
# [200]	training's rmse: 0.501617	valid_1's rmse: 0.534488
# [300]	training's rmse: 0.456014	valid_1's rmse: 0.506257
# [400]	training's rmse: 0.429735	valid_1's rmse: 0.497061
# [500]	training's rmse: 0.40939	valid_1's rmse: 0.493332
# [600]	training's rmse: 0.391915	valid_1's rmse: 0.490989
# [700]	training's rmse: 0.376029	valid_1's rmse: 0.490542
# [800]	training's rmse: 0.361551	valid_1's rmse: 0.489949
# [900]	training's rmse: 0.348066	valid_1's rmse: 0.489293
# [1000]	training's rmse: 0.335637	valid_1's rmse: 0.48919
# [1100]	training's rmse: 0.324263	valid_1's rmse: 0.489102
# [1200]	training's rmse: 0.313322	valid_1's rmse: 0.489019
# [1300]	training's rmse: 0.302937	valid_1's rmse: 0.489274
# Early stopping, best iteration is:
# [1170]	training's rmse: 0.316624	valid_1's rmse: 0.488898
# Model training63.427[s]
# score: 0.48890
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.647076	valid_1's rmse: 0.63491
# [200]	training's rmse: 0.50446	valid_1's rmse: 0.489287
# [300]	training's rmse: 0.459159	valid_1's rmse: 0.455039
# [400]	training's rmse: 0.432949	valid_1's rmse: 0.444856
# [500]	training's rmse: 0.412326	valid_1's rmse: 0.441097
# [600]	training's rmse: 0.394756	valid_1's rmse: 0.439579
# [700]	training's rmse: 0.378875	valid_1's rmse: 0.438687
# [800]	training's rmse: 0.364535	valid_1's rmse: 0.437323
# [900]	training's rmse: 0.351185	valid_1's rmse: 0.436657
# [1000]	training's rmse: 0.338638	valid_1's rmse: 0.436252
# [1100]	training's rmse: 0.326886	valid_1's rmse: 0.43527
# [1200]	training's rmse: 0.315855	valid_1's rmse: 0.435286
# [1300]	training's rmse: 0.305727	valid_1's rmse: 0.435888
# Early stopping, best iteration is:
# [1152]	training's rmse: 0.321061	valid_1's rmse: 0.435031
# Model training62.780[s]
# score: 0.43503
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.643114	valid_1's rmse: 0.687345
# [200]	training's rmse: 0.498907	valid_1's rmse: 0.571959
# [300]	training's rmse: 0.453106	valid_1's rmse: 0.547083
# [400]	training's rmse: 0.427453	valid_1's rmse: 0.539609
# [500]	training's rmse: 0.407175	valid_1's rmse: 0.537247
# [600]	training's rmse: 0.389393	valid_1's rmse: 0.536374
# [700]	training's rmse: 0.373667	valid_1's rmse: 0.535156
# [800]	training's rmse: 0.359599	valid_1's rmse: 0.535271
# [900]	training's rmse: 0.346264	valid_1's rmse: 0.534994
# [1000]	training's rmse: 0.33388	valid_1's rmse: 0.535022
# [1100]	training's rmse: 0.322267	valid_1's rmse: 0.53502
# [1200]	training's rmse: 0.311409	valid_1's rmse: 0.534694
# [1300]	training's rmse: 0.301136	valid_1's rmse: 0.534453
# [1400]	training's rmse: 0.291287	valid_1's rmse: 0.534075
# [1500]	training's rmse: 0.282046	valid_1's rmse: 0.534116
# [1600]	training's rmse: 0.272875	valid_1's rmse: 0.534259
# [1700]	training's rmse: 0.264278	valid_1's rmse: 0.534119
# Early stopping, best iteration is:
# [1511]	training's rmse: 0.281024	valid_1's rmse: 0.534058
# Model training78.458[s]
# score: 0.53406
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.642288	valid_1's rmse: 0.689301
# [200]	training's rmse: 0.498531	valid_1's rmse: 0.581054
# [300]	training's rmse: 0.452889	valid_1's rmse: 0.557017
# [400]	training's rmse: 0.427048	valid_1's rmse: 0.549388
# [500]	training's rmse: 0.406827	valid_1's rmse: 0.545046
# [600]	training's rmse: 0.389521	valid_1's rmse: 0.542799
# [700]	training's rmse: 0.373776	valid_1's rmse: 0.541177
# [800]	training's rmse: 0.359486	valid_1's rmse: 0.53998
# [900]	training's rmse: 0.346066	valid_1's rmse: 0.539083
# [1000]	training's rmse: 0.333829	valid_1's rmse: 0.538483
# [1100]	training's rmse: 0.322405	valid_1's rmse: 0.53843
# [1200]	training's rmse: 0.311544	valid_1's rmse: 0.537945
# [1300]	training's rmse: 0.301338	valid_1's rmse: 0.537849
# [1400]	training's rmse: 0.29152	valid_1's rmse: 0.537231
# [1500]	training's rmse: 0.28229	valid_1's rmse: 0.537262
# [1600]	training's rmse: 0.273268	valid_1's rmse: 0.536755
# [1700]	training's rmse: 0.264539	valid_1's rmse: 0.536464
# [1800]	training's rmse: 0.256372	valid_1's rmse: 0.536419
# [1900]	training's rmse: 0.248651	valid_1's rmse: 0.536205
# [2000]	training's rmse: 0.241008	valid_1's rmse: 0.5361
# [2100]	training's rmse: 0.233797	valid_1's rmse: 0.536153
# [2200]	training's rmse: 0.226805	valid_1's rmse: 0.536551
# Early stopping, best iteration is:
# [2044]	training's rmse: 0.237814	valid_1's rmse: 0.535881
# Model training74.815[s]
# score: 0.53588
# oof score:  0.487773

# %%
score_lgb.loc[score_lgb.fold == "oof"]
# Out:
#     seed fold  rmse score
# 15   650  oof    0.487068
# 31   651  oof    0.487853
# 47   652  oof    0.487627
# 63   653  oof    0.487400
# 79   654  oof    0.487665
# 95   655  oof    0.486989
# 111  656  oof    0.487283
# 127  657  oof    0.487409
# 143  658  oof    0.487318
# 159  659  oof    0.487529
# 175  660  oof    0.487537
# 191  661  oof    0.487062
# 207  662  oof    0.487562
# 223  663  oof    0.486692
# 239  664  oof    0.487018
# 255  665  oof    0.487773
# 256  avg  oof    0.484947

# %%
order = list(feat_imps_lgb.groupby("feature").mean().sort_values("importance", ascending=False).index)
plt.figure(figsize=(10, 120))
sns.barplot(x="importance", y="feature", data=feat_imps_lgb, order=order)
plt.title("{} importance".format("lgb"))
plt.tight_layout()

# %%
stage1 = pd.read_csv(OUTDIR / 'stage1.csv')
stage1['pred_888feat_lgb3'] = np.nan
stage1['pred_888feat_lgb3'][:t] = oof_pred_lgb
stage1['pred_888feat_lgb3'][t:] = test_pred_lgb
stage1.to_csv(OUTDIR / 'stage1.csv', index=False)

# %%
output = np.expm1(test_pred_lgb)
df_sub = pd.DataFrame()
df_sub["id"] = df_test["id"]
df_sub["cites"] = output
df_sub.to_csv(OUTDIR / 'stage1_888feat_lgb3.csv', index=False)
