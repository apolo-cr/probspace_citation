# %% [markdown]
# N_SPLITS=15、bagging_fraction=0.75、feature_fraction=0.75のLightGBMモデル（16seed Averaging）

# %% [markdown]
# # Libraries

# %%
# !pip3 uninstall --yes lightgbm && pip3 install --install-option=--gpu lightgbm
# Out:
# Uninstalling lightgbm-2.2.3:
#   Successfully uninstalled lightgbm-2.2.3
# /usr/local/lib/python3.7/dist-packages/pip/_internal/commands/install.py:283: UserWarning: Disabling all use of wheels due to the use of --build-options / --global-options / --install-options.
#   cmdoptions.check_install_build_global(options)
# Collecting lightgbm
#   Downloading https://files.pythonhosted.org/packages/d1/19/f19a8d12aecc7daaa5924c286c81e05ebb40ef3fe4cd4e33c8ed4e8db7ba/lightgbm-3.2.0.tar.gz (1.5MB)
#      |████████████████████████████████| 1.5MB 12.1MB/s
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm) (0.36.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.4.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /usr/local/lib/python3.7/dist-packages (from lightgbm) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.22.0->lightgbm) (1.0.1)
# Skipping wheel build for lightgbm, due to binaries being disabled for it.
# Installing collected packages: lightgbm
#     Running setup.py install for lightgbm ... done
# Successfully installed lightgbm-3.2.0

# %%
import warnings
warnings.filterwarnings('ignore')

import json
import pandas as pd
import numpy as np
import typing as tp
import time
from contextlib import contextmanager
from pathlib import Path
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import RidgeCV
import lightgbm as lgb

# %% [markdown]
# # Utils

# %%
DATADIR = Path('features')
OUTDIR = Path('stage1')

# %%
@contextmanager
def timer(logger=None, format_str='{:.3f}[s]', prefix=None, suffix=None):
    if prefix: format_str = str(prefix) + format_str
    if suffix: format_str = format_str + str(suffix)
    start = time.time()
    yield
    d = time.time() - start
    out_str = format_str.format(d)
    if logger:
        logger.info(out_str)
    else:
        print(out_str)

# %% [markdown]
# # Data Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "drive/My Drive/probspace_citations"
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/probspace_citations

# %%
df = pd.read_csv(DATADIR / 'base_df.csv')
multiple_word_categories_features = pd.read_csv(DATADIR / 'multiple_word_categories_features.csv')
groupby_feat_csv = pd.read_csv(DATADIR / 'groupby_feat.csv')
ALL_w2v = pd.read_csv(DATADIR / 'ALL_w2v.csv')
ALL_svd_fastText = pd.read_csv(DATADIR / 'ALL_svd_fastText.csv')
#ALL_pca_fastText = pd.read_csv(DATADIR / 'ALL_pca_fastText.csv')
ALL_svd_SciBERT = pd.read_csv(DATADIR / 'ALL_svd_SciBERT.csv')
w2v = pd.read_csv(DATADIR / 'w2v.csv')
svd_fastText = pd.read_csv(DATADIR / 'svd_fastText.csv')
#pca_fastText = pd.read_csv(DATADIR / 'pca_fastText.csv')
svd_SciBERT = pd.read_csv(DATADIR / 'svd_SciBERT.csv')
#tfidf = pd.read_csv(DATADIR / 'tfidf.csv')

# %%
df = pd.merge(df, multiple_word_categories_features, on='id', how='left')
df = pd.merge(df, groupby_feat_csv, on='id', how='left')
df = pd.merge(df, ALL_w2v, on='id', how='left')
df = pd.merge(df, ALL_svd_fastText, on='id', how='left')
#df = pd.merge(df, ALL_pca_fastText, on='id', how='left')
df = pd.merge(df, ALL_svd_SciBERT, on='id', how='left')
df = pd.merge(df, w2v, on='id', how='left')
df = pd.merge(df, svd_fastText, on='id', how='left')
#df = pd.merge(df, pca_fastText, on='id', how='left')
df = pd.merge(df, svd_SciBERT, on='id', how='left')
#df = pd.merge(df, tfidf, on='id', how='left')

# %%
drop_cols = [col for col in df.columns[df.T.duplicated()]]
df = df.drop(columns=drop_cols) # 同じ列を削除

df = df.loc[:, df.nunique() > 1] # 1種類の値しかない列を削除

# %% [markdown]
# ## 1st Stageの前に、doi_citesにRidge回帰をかけてみる

# %%
t = 15117
X_stage0 = np.log1p(df['doi_cites'])[:t].values.reshape(-1,1)
y_stage0 = np.log1p(df['cites'])[:t].values.reshape(-1,1)

# %%
alphas_list = [0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10, 100]
clf = RidgeCV(alphas=alphas_list, cv=5)
clf.fit(X_stage0, y_stage0)
# Out:
# RidgeCV(alphas=array([1.e-03, 5.e-03, 1.e-02, 5.e-02, 1.e-01, 5.e-01, 1.e+00, 5.e+00,
#        1.e+01, 1.e+02]),
#         cv=5, fit_intercept=True, gcv_mode=None, normalize=False, scoring=None,
#         store_cv_values=False)

# %%
oof = clf.predict(X_stage0)
pred = clf.predict(np.log1p(df['doi_cites'])[t:].values.reshape(-1,1))

# 参考
rmse = np.sqrt(mean_squared_error(y_stage0, oof))
print(rmse)
# Out:
# 0.6148520985897789

# %%
df['doi_cites'][:t] = oof.reshape(15117)
df['doi_cites'][t:] = pred.reshape(59084)

# %%
df_train_exists_cites = df[:t]
df_test = df[t:]

# %%
DROP_COLS = [
    'id',
    'submitter',
    'authors',
    'title',
    'comments',
    'journal-ref',
    'doi',
    'report-no',
    'categories',
    'license',
    'abstract',
    'versions',
    'update_date',
    'authors_parsed',
    'id_feat',
    'doi_feat_2',
]

TGT_COL = "cites"

# %%
X = df_train_exists_cites.drop(columns=DROP_COLS+['cites'])
X_test = df_test.drop(columns=DROP_COLS+['cites'])
y = np.log1p(df_train_exists_cites[TGT_COL])

print(f"train_feat: {X.shape}, test_feat: {X_test.shape}")
# Out:
# train_feat: (15117, 888), test_feat: (59084, 888)

# %% [markdown]
# # 1st Stage Model

# %% [markdown]
# ## Class

# %%
class TreeModel:
    """Wrapper for LightGBM/XGBoost/CATBoost"""
    def __init__(self, model_type: str):
        self.model_type = model_type
        self.trn_data = None
        self.val_data = None
        self.model = None

    def train(self,
              params: dict,
              X_train: pd.DataFrame, y_train: np.ndarray,
              X_val: pd.DataFrame, y_val: np.ndarray,
              train_weight: tp.Optional[np.ndarray] = None,
              val_weight: tp.Optional[np.ndarray] = None,
              train_params: dict = {}):
        if self.model_type == "lgb":
            self.trn_data = lgb.Dataset(X_train, label=y_train, weight=train_weight)
            self.val_data = lgb.Dataset(X_val, label=y_val, weight=val_weight)
            self.model = lgb.train(params=params,
                                   train_set=self.trn_data,
                                   valid_sets=[self.trn_data, self.val_data],
                                   categorical_feature = CATEGORICAL_COLS,
                                   **train_params)
        elif self.model_type == "xgb":
            self.trn_data = xgb.DMatrix(X_train, y_train, weight=train_weight)
            self.val_data = xgb.DMatrix(X_val, y_val, weight=val_weight)
            self.model = xgb.train(params=params,
                                   dtrain=self.trn_data,
                                   evals=[(self.trn_data, "train"), (self.val_data, "val")],
                                   **train_params)
        elif self.model_type == "cat":
            self.trn_data = Pool(X_train, label=y_train, group_id=[0] * len(X_train))
            self.val_data =  Pool(X_val, label=y_val, group_id=[0] * len(X_val))
            self.model = CatBoost(params)
            self.model.fit(
                self.trn_data, eval_set=[self.val_data], use_best_model=True, **train_params)
        else:
            raise NotImplementedError

    def predict(self, X: pd.DataFrame):
        if self.model_type == "lgb":
            return self.model.predict(
                X, num_iteration=self.model.best_iteration)
        elif self.model_type == "xgb":
            X_DM = xgb.DMatrix(X)
            return self.model.predict(
                X_DM, ntree_limit=self.model.best_ntree_limit)
        elif self.model_type == "cat":
            return self.model.predict(X)
        else:
            raise NotImplementedError

    @property
    def feature_names_(self):
        if self.model_type == "lgb":
            return self.model.feature_name()
        elif self.model_type == "xgb":
            return list(self.model.get_score(importance_type="gain").keys())
        elif self.model_type == "cat":
             return self.model.feature_names_
        else:
            raise NotImplementedError

    @property
    def feature_importances_(self):
        if self.model_type == "lgb":
            return self.model.feature_importance(importance_type="gain")
        elif self.model_type == "xgb":
            return list(self.model.get_score(importance_type="gain").values())
        elif self.model_type == "cat":
            return self.model.feature_importances_
        else:
            raise NotImplementedError

# %%
CATEGORICAL_COLS = [
    #'doi_feat',
]

N_SPLITS = 15
RANDOM_SEED_LIST_LGB = [950,951,952,953,954,955,956,957,958,959,960,961,962,963,964,965,966,967,968,969,970]

MODEL_PARAMS = {
    "lgb": {
        'seed': RANDOM_SEED_LIST_LGB[1],
        'learning_rate': 0.01,
        'bagging_fraction': 0.75,
        'bagging_freq': 7,
        'feature_fraction': 0.75,
        'feature_pre_filter': False,
        'lambda_l1': 5.303273671011905e-07,
        'lambda_l2': 0.0036041492368018907,
        'metric': 'rmse',
        'min_child_samples': 24,
        'num_leaves': 36,
        'max_bin': 63,
        'objective': 'regression',
        'verbosity': -1,
        'device': 'gpu',
        'gpu_device_id': 0,
    },
}

TRAIN_PARAMS = {
    "lgb": {
        "num_boost_round": 20000,
        "early_stopping_rounds": 200,
        "verbose_eval": 100,
    },
}

# %%
def target_stratify_kfold(df, seed,n_bins=N_SPLITS*100, folds=N_SPLITS):
    _df = pd.DataFrame()
    _df["bins"] = pd.cut(df.cites, n_bins, labels=False)
    fold = np.zeros(len(df), dtype=int)
    skf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=seed)
    for i_fold, (_, val_idx) in enumerate(skf.split(_df.bins, _df.bins)):
        fold[val_idx] = i_fold
    return fold

# %%
def run_train_and_inference(X, X_test, y, use_model, model_params, train_params, seed_list, n_splits):
    
    oof_pred_arr = np.zeros(len(X))
    test_pred_arr = np.zeros(len(X_test))
    feature_importances = pd.DataFrame()
    score_list = []
    
    for seed in seed_list:
        if use_model == "cat":
            model_params['random_state'] = seed
        else:
            model_params["seed"] = seed
        folds_idx = target_stratify_kfold(df=df_train_exists_cites, seed=seed)
        tmp_oof_pred = np.zeros(len(X))
        tmp_test_pred = np.zeros(len(X_test))

        for fold in range(N_SPLITS):
            tr_idx = np.argwhere(folds_idx != fold).reshape(-1)
            va_idx = np.argwhere(folds_idx == fold).reshape(-1)
            X_trn, X_val = X.loc[tr_idx], X.loc[va_idx]
            y_trn, y_val = y.loc[tr_idx], y.loc[va_idx]

            model = TreeModel(model_type=use_model)
            with timer(prefix="Model training"):
                model.train(
                    params=model_params, X_train=X_trn, y_train=y_trn,
                    X_val=X_val, y_val=y_val, train_params=train_params)
            fi_tmp = pd.DataFrame()
            fi_tmp["feature"] = model.feature_names_
            fi_tmp["importance"] = model.feature_importances_
            fi_tmp["fold"] = fold
            fi_tmp["seed"] = seed
            feature_importances = feature_importances.append(fi_tmp)

            val_pred = model.predict(X_val)
            score = mean_squared_error(y_val, val_pred, squared=False)
            print(f"score: {score:.5f}")
            score_list.append([seed, fold, score])
            tmp_oof_pred[va_idx] = val_pred
            tmp_test_pred += model.predict(X_test)
            
        oof_score = mean_squared_error(y, tmp_oof_pred, squared=False)
        print(f"oof score: {oof_score: 5f}")
        score_list.append([seed, "oof", oof_score])

        oof_pred_arr += tmp_oof_pred
        test_pred_arr += tmp_test_pred / n_splits

    oof_pred_arr /= len(seed_list)
    test_pred_arr /= len(seed_list)
    
    oof_score = mean_squared_error(y, oof_pred_arr, squared=False)
    score_list.append(["avg", "oof", oof_score])
    score_df = pd.DataFrame(
        score_list, columns=["seed", "fold", "rmse score"])
    
    return oof_pred_arr, test_pred_arr, score_df, feature_importances

# %% [markdown]
# ## LightGBM

# %%
oof_pred_lgb, test_pred_lgb, score_lgb, feat_imps_lgb = run_train_and_inference(
    X, X_test, y, "lgb", MODEL_PARAMS["lgb"], TRAIN_PARAMS["lgb"], RANDOM_SEED_LIST_LGB, N_SPLITS)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645811	valid_1's rmse: 0.648917
# [200]	training's rmse: 0.502236	valid_1's rmse: 0.524861
# [300]	training's rmse: 0.456231	valid_1's rmse: 0.497764
# [400]	training's rmse: 0.429902	valid_1's rmse: 0.490177
# [500]	training's rmse: 0.409211	valid_1's rmse: 0.486501
# [600]	training's rmse: 0.391488	valid_1's rmse: 0.484123
# [700]	training's rmse: 0.375698	valid_1's rmse: 0.483425
# [800]	training's rmse: 0.361429	valid_1's rmse: 0.483329
# [900]	training's rmse: 0.348212	valid_1's rmse: 0.483138
# [1000]	training's rmse: 0.335588	valid_1's rmse: 0.482833
# [1100]	training's rmse: 0.323736	valid_1's rmse: 0.483169
# Early stopping, best iteration is:
# [975]	training's rmse: 0.338631	valid_1's rmse: 0.482727
# Model training56.573[s]
# score: 0.48273
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644391	valid_1's rmse: 0.668131
# [200]	training's rmse: 0.501641	valid_1's rmse: 0.538366
# [300]	training's rmse: 0.455881	valid_1's rmse: 0.508076
# [400]	training's rmse: 0.429724	valid_1's rmse: 0.499531
# [500]	training's rmse: 0.409346	valid_1's rmse: 0.495199
# [600]	training's rmse: 0.391768	valid_1's rmse: 0.493654
# [700]	training's rmse: 0.375837	valid_1's rmse: 0.492769
# [800]	training's rmse: 0.361736	valid_1's rmse: 0.492176
# [900]	training's rmse: 0.348285	valid_1's rmse: 0.491035
# [1000]	training's rmse: 0.335906	valid_1's rmse: 0.490598
# [1100]	training's rmse: 0.324311	valid_1's rmse: 0.490129
# [1200]	training's rmse: 0.313401	valid_1's rmse: 0.49029
# [1300]	training's rmse: 0.302974	valid_1's rmse: 0.489987
# Early stopping, best iteration is:
# [1154]	training's rmse: 0.318315	valid_1's rmse: 0.489882
# Model training64.214[s]
# score: 0.48988
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.643773	valid_1's rmse: 0.670326
# [200]	training's rmse: 0.500873	valid_1's rmse: 0.544976
# [300]	training's rmse: 0.455226	valid_1's rmse: 0.517696
# [400]	training's rmse: 0.429073	valid_1's rmse: 0.508805
# [500]	training's rmse: 0.409149	valid_1's rmse: 0.505327
# [600]	training's rmse: 0.391649	valid_1's rmse: 0.502884
# [700]	training's rmse: 0.376118	valid_1's rmse: 0.501794
# [1000]	training's rmse: 0.334934	valid_1's rmse: 0.499397
# [1100]	training's rmse: 0.32305	valid_1's rmse: 0.498652
# [1200]	training's rmse: 0.312004	valid_1's rmse: 0.498579
# [1300]	training's rmse: 0.3019	valid_1's rmse: 0.498816
# [1400]	training's rmse: 0.29215	valid_1's rmse: 0.499038
# Early stopping, best iteration is:
# [1211]	training's rmse: 0.310836	valid_1's rmse: 0.498461
# Model training66.195[s]
# score: 0.49846
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.643858	valid_1's rmse: 0.652772
# [200]	training's rmse: 0.500826	valid_1's rmse: 0.535495
# [300]	training's rmse: 0.455273	valid_1's rmse: 0.512606
# [400]	training's rmse: 0.428974	valid_1's rmse: 0.505835
# [500]	training's rmse: 0.408589	valid_1's rmse: 0.503153
# [600]	training's rmse: 0.391017	valid_1's rmse: 0.501602
# [700]	training's rmse: 0.375323	valid_1's rmse: 0.500002
# [800]	training's rmse: 0.360939	valid_1's rmse: 0.498181
# [900]	training's rmse: 0.34746	valid_1's rmse: 0.498392
# [1000]	training's rmse: 0.335078	valid_1's rmse: 0.497592
# [1100]	training's rmse: 0.323825	valid_1's rmse: 0.497286
# [1200]	training's rmse: 0.312873	valid_1's rmse: 0.496845
# [1300]	training's rmse: 0.302659	valid_1's rmse: 0.496809
# [1400]	training's rmse: 0.292467	valid_1's rmse: 0.496875
# Early stopping, best iteration is:
# [1246]	training's rmse: 0.308102	valid_1's rmse: 0.496578
# Model training67.790[s]
# score: 0.49658
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644613	valid_1's rmse: 0.660468
# [200]	training's rmse: 0.50099	valid_1's rmse: 0.542344
# [300]	training's rmse: 0.454917	valid_1's rmse: 0.518114
# [400]	training's rmse: 0.42878	valid_1's rmse: 0.511847
# [500]	training's rmse: 0.408453	valid_1's rmse: 0.508863
# [600]	training's rmse: 0.390914	valid_1's rmse: 0.505902
# [700]	training's rmse: 0.375251	valid_1's rmse: 0.504509
# [800]	training's rmse: 0.360993	valid_1's rmse: 0.504233
# [900]	training's rmse: 0.347782	valid_1's rmse: 0.503861
# [1000]	training's rmse: 0.33531	valid_1's rmse: 0.503671
# [1100]	training's rmse: 0.323709	valid_1's rmse: 0.503589
# [1200]	training's rmse: 0.312546	valid_1's rmse: 0.503387
# [1300]	training's rmse: 0.302311	valid_1's rmse: 0.502844
# [1400]	training's rmse: 0.292367	valid_1's rmse: 0.502233
# [1500]	training's rmse: 0.282905	valid_1's rmse: 0.502032
# [1600]	training's rmse: 0.274014	valid_1's rmse: 0.502613
# Early stopping, best iteration is:
# [1473]	training's rmse: 0.285208	valid_1's rmse: 0.501957
# Model training74.937[s]
# score: 0.50196
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644589	valid_1's rmse: 0.662726
# [200]	training's rmse: 0.501234	valid_1's rmse: 0.534605
# [300]	training's rmse: 0.455401	valid_1's rmse: 0.50594
# [400]	training's rmse: 0.429519	valid_1's rmse: 0.4967
# [500]	training's rmse: 0.409397	valid_1's rmse: 0.492112
# [600]	training's rmse: 0.391587	valid_1's rmse: 0.48939
# [700]	training's rmse: 0.375617	valid_1's rmse: 0.487758
# [800]	training's rmse: 0.361404	valid_1's rmse: 0.486371
# [900]	training's rmse: 0.348187	valid_1's rmse: 0.485013
# [1000]	training's rmse: 0.33594	valid_1's rmse: 0.484504
# [1100]	training's rmse: 0.324454	valid_1's rmse: 0.484099
# [1200]	training's rmse: 0.313506	valid_1's rmse: 0.483823
# [1300]	training's rmse: 0.303185	valid_1's rmse: 0.483772
# [1400]	training's rmse: 0.293325	valid_1's rmse: 0.483377
# [1500]	training's rmse: 0.283775	valid_1's rmse: 0.483185
# [1600]	training's rmse: 0.274916	valid_1's rmse: 0.482935
# [1700]	training's rmse: 0.266239	valid_1's rmse: 0.482751
# [1800]	training's rmse: 0.25799	valid_1's rmse: 0.482401
# [1900]	training's rmse: 0.249984	valid_1's rmse: 0.48225
# [2000]	training's rmse: 0.242207	valid_1's rmse: 0.48219
# [2100]	training's rmse: 0.234827	valid_1's rmse: 0.482221
# Early stopping, best iteration is:
# [1922]	training's rmse: 0.248219	valid_1's rmse: 0.481951
# Model training96.006[s]
# score: 0.48195
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.64468	valid_1's rmse: 0.653248
# [200]	training's rmse: 0.502202	valid_1's rmse: 0.522772
# [300]	training's rmse: 0.456618	valid_1's rmse: 0.491613
# [400]	training's rmse: 0.430836	valid_1's rmse: 0.481474
# [500]	training's rmse: 0.41049	valid_1's rmse: 0.477001
# [600]	training's rmse: 0.393055	valid_1's rmse: 0.474253
# [700]	training's rmse: 0.377267	valid_1's rmse: 0.473139
# [800]	training's rmse: 0.362827	valid_1's rmse: 0.471256
# [900]	training's rmse: 0.349824	valid_1's rmse: 0.470326
# [1000]	training's rmse: 0.337664	valid_1's rmse: 0.470053
# [1100]	training's rmse: 0.326204	valid_1's rmse: 0.470239
# [1200]	training's rmse: 0.315401	valid_1's rmse: 0.470129
# [1300]	training's rmse: 0.304991	valid_1's rmse: 0.469851
# [1400]	training's rmse: 0.295038	valid_1's rmse: 0.469306
# [1500]	training's rmse: 0.285423	valid_1's rmse: 0.468964
# [1600]	training's rmse: 0.276482	valid_1's rmse: 0.468566
# [1700]	training's rmse: 0.267789	valid_1's rmse: 0.468925
# [1800]	training's rmse: 0.259688	valid_1's rmse: 0.46903
# Early stopping, best iteration is:
# [1634]	training's rmse: 0.273588	valid_1's rmse: 0.468448
# Model training84.221[s]
# score: 0.46845
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644961	valid_1's rmse: 0.644594
# [200]	training's rmse: 0.502227	valid_1's rmse: 0.517044
# [300]	training's rmse: 0.456235	valid_1's rmse: 0.490828
# [400]	training's rmse: 0.429972	valid_1's rmse: 0.483302
# [500]	training's rmse: 0.409607	valid_1's rmse: 0.480316
# [600]	training's rmse: 0.391904	valid_1's rmse: 0.478851
# [700]	training's rmse: 0.376123	valid_1's rmse: 0.478189
# [800]	training's rmse: 0.361755	valid_1's rmse: 0.4779
# [900]	training's rmse: 0.348475	valid_1's rmse: 0.477437
# [1000]	training's rmse: 0.336208	valid_1's rmse: 0.477446
# [1100]	training's rmse: 0.324783	valid_1's rmse: 0.477113
# [1200]	training's rmse: 0.313705	valid_1's rmse: 0.477375
# Early stopping, best iteration is:
# [1060]	training's rmse: 0.329161	valid_1's rmse: 0.477083
# Model training60.562[s]
# score: 0.47708
# oof score:  0.487901
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644825	valid_1's rmse: 0.666758
# [200]	training's rmse: 0.501347	valid_1's rmse: 0.538854
# [300]	training's rmse: 0.455514	valid_1's rmse: 0.51061
# [400]	training's rmse: 0.429398	valid_1's rmse: 0.502037
# [500]	training's rmse: 0.409039	valid_1's rmse: 0.499252
# [600]	training's rmse: 0.39109	valid_1's rmse: 0.498668
# [700]	training's rmse: 0.375346	valid_1's rmse: 0.498384
# ...
# [1400]	training's rmse: 0.294665	valid_1's rmse: 0.469882
# [1500]	training's rmse: 0.285353	valid_1's rmse: 0.469681
# [1600]	training's rmse: 0.276461	valid_1's rmse: 0.469811
# [1700]	training's rmse: 0.267678	valid_1's rmse: 0.469738
# Early stopping, best iteration is:
# [1512]	training's rmse: 0.28422	valid_1's rmse: 0.469561
# Model training59.643[s]
# score: 0.46956
# oof score:  0.487494
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.641706	valid_1's rmse: 0.680085
# [200]	training's rmse: 0.498294	valid_1's rmse: 0.572197
# [300]	training's rmse: 0.453314	valid_1's rmse: 0.5508
# [400]	training's rmse: 0.427618	valid_1's rmse: 0.543841
# [500]	training's rmse: 0.40757	valid_1's rmse: 0.538557
# [600]	training's rmse: 0.390165	valid_1's rmse: 0.536062
# [700]	training's rmse: 0.37454	valid_1's rmse: 0.534088
# [800]	training's rmse: 0.360192	valid_1's rmse: 0.533125
# [900]	training's rmse: 0.3469	valid_1's rmse: 0.532082
# [1000]	training's rmse: 0.334722	valid_1's rmse: 0.53146
# [1100]	training's rmse: 0.323429	valid_1's rmse: 0.531105
# [1200]	training's rmse: 0.312519	valid_1's rmse: 0.531185
# [1300]	training's rmse: 0.302242	valid_1's rmse: 0.53083
# Early stopping, best iteration is:
# [1120]	training's rmse: 0.321149	valid_1's rmse: 0.53078
# Model training62.461[s]
# score: 0.53078
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.643078	valid_1's rmse: 0.683911
# [200]	training's rmse: 0.499327	valid_1's rmse: 0.564165
# [300]	training's rmse: 0.453317	valid_1's rmse: 0.535226
# [400]	training's rmse: 0.427571	valid_1's rmse: 0.523905
# [500]	training's rmse: 0.407591	valid_1's rmse: 0.518146
# [600]	training's rmse: 0.390306	valid_1's rmse: 0.515602
# [700]	training's rmse: 0.374616	valid_1's rmse: 0.513349
# [800]	training's rmse: 0.360358	valid_1's rmse: 0.512645
# [900]	training's rmse: 0.347309	valid_1's rmse: 0.512196
# [1000]	training's rmse: 0.334858	valid_1's rmse: 0.511974
# [1100]	training's rmse: 0.323432	valid_1's rmse: 0.511303
# [1200]	training's rmse: 0.312484	valid_1's rmse: 0.511018
# [1300]	training's rmse: 0.302201	valid_1's rmse: 0.510551
# [1400]	training's rmse: 0.292115	valid_1's rmse: 0.510567
# [1500]	training's rmse: 0.282742	valid_1's rmse: 0.510489
# [1600]	training's rmse: 0.273961	valid_1's rmse: 0.510477
# [1700]	training's rmse: 0.265249	valid_1's rmse: 0.510155
# [1800]	training's rmse: 0.25707	valid_1's rmse: 0.510656
# Early stopping, best iteration is:
# [1690]	training's rmse: 0.266113	valid_1's rmse: 0.510066
# Model training86.518[s]
# score: 0.51007
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.64479	valid_1's rmse: 0.656907
# [200]	training's rmse: 0.501724	valid_1's rmse: 0.52739
# [300]	training's rmse: 0.455857	valid_1's rmse: 0.498138
# [400]	training's rmse: 0.429903	valid_1's rmse: 0.490041
# [500]	training's rmse: 0.409843	valid_1's rmse: 0.486075
# [600]	training's rmse: 0.392065	valid_1's rmse: 0.484675
# [700]	training's rmse: 0.376203	valid_1's rmse: 0.48352
# [800]	training's rmse: 0.36174	valid_1's rmse: 0.482486
# [900]	training's rmse: 0.348457	valid_1's rmse: 0.481433
# [1000]	training's rmse: 0.336037	valid_1's rmse: 0.481286
# [1100]	training's rmse: 0.324484	valid_1's rmse: 0.480894
# [1200]	training's rmse: 0.313446	valid_1's rmse: 0.480542
# [1300]	training's rmse: 0.303042	valid_1's rmse: 0.479948
# [1400]	training's rmse: 0.293075	valid_1's rmse: 0.479196
# [1500]	training's rmse: 0.283697	valid_1's rmse: 0.479168
# [1600]	training's rmse: 0.274739	valid_1's rmse: 0.478922
# [1700]	training's rmse: 0.266141	valid_1's rmse: 0.479037
# Early stopping, best iteration is:
# [1560]	training's rmse: 0.278248	valid_1's rmse: 0.478808
# Model training80.876[s]
# score: 0.47881
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.643507	valid_1's rmse: 0.667061
# [200]	training's rmse: 0.500254	valid_1's rmse: 0.548101
# [300]	training's rmse: 0.454533	valid_1's rmse: 0.522872
# [400]	training's rmse: 0.428592	valid_1's rmse: 0.514619
# [500]	training's rmse: 0.408258	valid_1's rmse: 0.510766
# [600]	training's rmse: 0.390728	valid_1's rmse: 0.508167
# [700]	training's rmse: 0.374855	valid_1's rmse: 0.507398
# [800]	training's rmse: 0.360581	valid_1's rmse: 0.507037
# [900]	training's rmse: 0.347374	valid_1's rmse: 0.506598
# [1000]	training's rmse: 0.335042	valid_1's rmse: 0.506048
# [1100]	training's rmse: 0.323254	valid_1's rmse: 0.506378
# [1200]	training's rmse: 0.312435	valid_1's rmse: 0.505989
# [1300]	training's rmse: 0.301884	valid_1's rmse: 0.506041
# [1400]	training's rmse: 0.292059	valid_1's rmse: 0.505844
# [1500]	training's rmse: 0.282679	valid_1's rmse: 0.505842
# [1600]	training's rmse: 0.273801	valid_1's rmse: 0.505708
# [1700]	training's rmse: 0.265173	valid_1's rmse: 0.505942
# [1800]	training's rmse: 0.256814	valid_1's rmse: 0.506035
# Early stopping, best iteration is:
# [1610]	training's rmse: 0.272976	valid_1's rmse: 0.505616
# Model training82.997[s]
# score: 0.50562
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645065	valid_1's rmse: 0.647126
# [200]	training's rmse: 0.502217	valid_1's rmse: 0.51965
# [300]	training's rmse: 0.455922	valid_1's rmse: 0.492262
# [400]	training's rmse: 0.430027	valid_1's rmse: 0.483692
# [500]	training's rmse: 0.409472	valid_1's rmse: 0.479784
# [600]	training's rmse: 0.392116	valid_1's rmse: 0.478554
# [700]	training's rmse: 0.37634	valid_1's rmse: 0.478299
# [800]	training's rmse: 0.361939	valid_1's rmse: 0.476676
# [900]	training's rmse: 0.348388	valid_1's rmse: 0.476078
# [1000]	training's rmse: 0.335919	valid_1's rmse: 0.475482
# [1100]	training's rmse: 0.324502	valid_1's rmse: 0.475076
# [1200]	training's rmse: 0.313443	valid_1's rmse: 0.474838
# [1300]	training's rmse: 0.303163	valid_1's rmse: 0.474748
# [1400]	training's rmse: 0.293182	valid_1's rmse: 0.47481
# Early stopping, best iteration is:
# [1248]	training's rmse: 0.308429	valid_1's rmse: 0.474631
# Model training67.384[s]
# score: 0.47463
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645368	valid_1's rmse: 0.645903
# [200]	training's rmse: 0.501588	valid_1's rmse: 0.525547
# [300]	training's rmse: 0.455615	valid_1's rmse: 0.500918
# [400]	training's rmse: 0.429648	valid_1's rmse: 0.493361
# [500]	training's rmse: 0.409275	valid_1's rmse: 0.489005
# [600]	training's rmse: 0.391601	valid_1's rmse: 0.486765
# [700]	training's rmse: 0.375912	valid_1's rmse: 0.485871
# [800]	training's rmse: 0.361295	valid_1's rmse: 0.484931
# [900]	training's rmse: 0.34813	valid_1's rmse: 0.484589
# [1000]	training's rmse: 0.335674	valid_1's rmse: 0.484541
# [1100]	training's rmse: 0.323965	valid_1's rmse: 0.484223
# [1200]	training's rmse: 0.313008	valid_1's rmse: 0.48432
# [1300]	training's rmse: 0.302646	valid_1's rmse: 0.48455
# Early stopping, best iteration is:
# [1175]	training's rmse: 0.315708	valid_1's rmse: 0.483955
# Model training64.816[s]
# score: 0.48395
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645093	valid_1's rmse: 0.651649
# [200]	training's rmse: 0.501725	valid_1's rmse: 0.52831
# [300]	training's rmse: 0.45554	valid_1's rmse: 0.503461
# [400]	training's rmse: 0.429481	valid_1's rmse: 0.496217
# [500]	training's rmse: 0.409122	valid_1's rmse: 0.492957
# [600]	training's rmse: 0.39153	valid_1's rmse: 0.491322
# [700]	training's rmse: 0.375657	valid_1's rmse: 0.489995
# [800]	training's rmse: 0.361231	valid_1's rmse: 0.489606
# [900]	training's rmse: 0.34801	valid_1's rmse: 0.489122
# [1000]	training's rmse: 0.335399	valid_1's rmse: 0.488629
# [1100]	training's rmse: 0.323595	valid_1's rmse: 0.488122
# [1200]	training's rmse: 0.312768	valid_1's rmse: 0.4878
# [1300]	training's rmse: 0.302512	valid_1's rmse: 0.487695
# [1400]	training's rmse: 0.292852	valid_1's rmse: 0.487772
# Early stopping, best iteration is:
# [1268]	training's rmse: 0.30558	valid_1's rmse: 0.487563
# Model training68.648[s]
# score: 0.48756
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.6441	valid_1's rmse: 0.661959
# [200]	training's rmse: 0.500264	valid_1's rmse: 0.542555
# [300]	training's rmse: 0.454415	valid_1's rmse: 0.517108
# [400]	training's rmse: 0.428447	valid_1's rmse: 0.509785
# [500]	training's rmse: 0.408029	valid_1's rmse: 0.505952
# [600]	training's rmse: 0.390386	valid_1's rmse: 0.503489
# [700]	training's rmse: 0.374864	valid_1's rmse: 0.502313
# [800]	training's rmse: 0.360555	valid_1's rmse: 0.501244
# [900]	training's rmse: 0.347446	valid_1's rmse: 0.501108
# [1000]	training's rmse: 0.335105	valid_1's rmse: 0.500751
# [1100]	training's rmse: 0.323543	valid_1's rmse: 0.500758
# [1200]	training's rmse: 0.312774	valid_1's rmse: 0.500348
# [1300]	training's rmse: 0.302351	valid_1's rmse: 0.500333
# [1400]	training's rmse: 0.292482	valid_1's rmse: 0.500478
# Early stopping, best iteration is:
# [1264]	training's rmse: 0.305987	valid_1's rmse: 0.500136
# Model training68.411[s]
# score: 0.50014
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.647162	valid_1's rmse: 0.634637
# [200]	training's rmse: 0.50398	valid_1's rmse: 0.492291
# [300]	training's rmse: 0.458183	valid_1's rmse: 0.458641
# [400]	training's rmse: 0.432358	valid_1's rmse: 0.447918
# [500]	training's rmse: 0.411703	valid_1's rmse: 0.442958
# [600]	training's rmse: 0.393964	valid_1's rmse: 0.440854
# [700]	training's rmse: 0.378202	valid_1's rmse: 0.439831
# [800]	training's rmse: 0.363926	valid_1's rmse: 0.4384
# [900]	training's rmse: 0.350602	valid_1's rmse: 0.437628
# [1000]	training's rmse: 0.338304	valid_1's rmse: 0.437322
# [1100]	training's rmse: 0.326561	valid_1's rmse: 0.437188
# [1200]	training's rmse: 0.315581	valid_1's rmse: 0.437462
# [1300]	training's rmse: 0.305153	valid_1's rmse: 0.437668
# Early stopping, best iteration is:
# [1112]	training's rmse: 0.325248	valid_1's rmse: 0.437035
# Model training61.589[s]
# score: 0.43703
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644552	valid_1's rmse: 0.651101
# [200]	training's rmse: 0.50174	valid_1's rmse: 0.528389
# [300]	training's rmse: 0.455731	valid_1's rmse: 0.504201
# [400]	training's rmse: 0.429843	valid_1's rmse: 0.496742
# [500]	training's rmse: 0.409598	valid_1's rmse: 0.492867
# [600]	training's rmse: 0.392354	valid_1's rmse: 0.490851
# [700]	training's rmse: 0.376568	valid_1's rmse: 0.48942
# [800]	training's rmse: 0.362156	valid_1's rmse: 0.487827
# [900]	training's rmse: 0.348917	valid_1's rmse: 0.486583
# [1000]	training's rmse: 0.336579	valid_1's rmse: 0.486061
# [1100]	training's rmse: 0.324978	valid_1's rmse: 0.486087
# [1200]	training's rmse: 0.313959	valid_1's rmse: 0.485194
# [1300]	training's rmse: 0.303495	valid_1's rmse: 0.484873
# [1400]	training's rmse: 0.293744	valid_1's rmse: 0.48426
# [1500]	training's rmse: 0.284457	valid_1's rmse: 0.48447
# [1600]	training's rmse: 0.275419	valid_1's rmse: 0.484351
# [1700]	training's rmse: 0.26684	valid_1's rmse: 0.484043
# [1800]	training's rmse: 0.258784	valid_1's rmse: 0.484213
# Early stopping, best iteration is:
# [1660]	training's rmse: 0.270301	valid_1's rmse: 0.483952
# Model training84.854[s]
# score: 0.48395
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.64542	valid_1's rmse: 0.640978
# [200]	training's rmse: 0.502606	valid_1's rmse: 0.508041
# [300]	training's rmse: 0.456975	valid_1's rmse: 0.476747
# [400]	training's rmse: 0.431209	valid_1's rmse: 0.467029
# [500]	training's rmse: 0.410809	valid_1's rmse: 0.462844
# [600]	training's rmse: 0.393213	valid_1's rmse: 0.460766
# [700]	training's rmse: 0.377483	valid_1's rmse: 0.459695
# [800]	training's rmse: 0.362906	valid_1's rmse: 0.459021
# [900]	training's rmse: 0.349578	valid_1's rmse: 0.458566
# [1000]	training's rmse: 0.337283	valid_1's rmse: 0.458035
# [1100]	training's rmse: 0.325572	valid_1's rmse: 0.458206
# [1200]	training's rmse: 0.314706	valid_1's rmse: 0.457719
# [1300]	training's rmse: 0.304225	valid_1's rmse: 0.457611
# [1400]	training's rmse: 0.294248	valid_1's rmse: 0.45733
# [1500]	training's rmse: 0.284709	valid_1's rmse: 0.457323
# [1600]	training's rmse: 0.275492	valid_1's rmse: 0.457831
# Early stopping, best iteration is:
# [1427]	training's rmse: 0.291536	valid_1's rmse: 0.457172
# Model training56.825[s]
# score: 0.45717
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.645873	valid_1's rmse: 0.641318
# [200]	training's rmse: 0.503082	valid_1's rmse: 0.506936
# [300]	training's rmse: 0.457316	valid_1's rmse: 0.475502
# [400]	training's rmse: 0.43107	valid_1's rmse: 0.466014
# [500]	training's rmse: 0.410585	valid_1's rmse: 0.461925
# [600]	training's rmse: 0.392774	valid_1's rmse: 0.459867
# [700]	training's rmse: 0.376977	valid_1's rmse: 0.459651
# [800]	training's rmse: 0.362809	valid_1's rmse: 0.459291
# [900]	training's rmse: 0.349605	valid_1's rmse: 0.459209
# [1000]	training's rmse: 0.337072	valid_1's rmse: 0.458997
# [1100]	training's rmse: 0.325255	valid_1's rmse: 0.458728
# [1200]	training's rmse: 0.314189	valid_1's rmse: 0.458657
# [1300]	training's rmse: 0.303673	valid_1's rmse: 0.458566
# [1400]	training's rmse: 0.293569	valid_1's rmse: 0.458394
# [1500]	training's rmse: 0.284105	valid_1's rmse: 0.458432
# [1600]	training's rmse: 0.275006	valid_1's rmse: 0.458461
# [1700]	training's rmse: 0.266171	valid_1's rmse: 0.458533
# Early stopping, best iteration is:
# [1539]	training's rmse: 0.280425	valid_1's rmse: 0.458154
# Model training79.938[s]
# score: 0.45815
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.644187	valid_1's rmse: 0.675276
# [200]	training's rmse: 0.501513	valid_1's rmse: 0.538266
# [300]	training's rmse: 0.455767	valid_1's rmse: 0.505179
# [400]	training's rmse: 0.429916	valid_1's rmse: 0.494618
# [500]	training's rmse: 0.409534	valid_1's rmse: 0.490217
# [600]	training's rmse: 0.392185	valid_1's rmse: 0.487613
# [700]	training's rmse: 0.37615	valid_1's rmse: 0.486511
# [800]	training's rmse: 0.36163	valid_1's rmse: 0.485703
# [900]	training's rmse: 0.348414	valid_1's rmse: 0.485423
# [1000]	training's rmse: 0.336106	valid_1's rmse: 0.485683
# [1100]	training's rmse: 0.324306	valid_1's rmse: 0.48513
# [1200]	training's rmse: 0.313336	valid_1's rmse: 0.485225
# Early stopping, best iteration is:
# [1092]	training's rmse: 0.325254	valid_1's rmse: 0.485017
# Model training61.411[s]
# score: 0.48502
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.643003	valid_1's rmse: 0.66802
# [200]	training's rmse: 0.499545	valid_1's rmse: 0.556333
# [300]	training's rmse: 0.453788	valid_1's rmse: 0.533829
# [400]	training's rmse: 0.427783	valid_1's rmse: 0.52753
# [500]	training's rmse: 0.407512	valid_1's rmse: 0.52269
# [600]	training's rmse: 0.390026	valid_1's rmse: 0.5211
# [700]	training's rmse: 0.374601	valid_1's rmse: 0.519092
# [800]	training's rmse: 0.360147	valid_1's rmse: 0.517604
# [900]	training's rmse: 0.346835	valid_1's rmse: 0.517146
# [1000]	training's rmse: 0.334746	valid_1's rmse: 0.516992
# [1100]	training's rmse: 0.32314	valid_1's rmse: 0.517044
# [1200]	training's rmse: 0.312336	valid_1's rmse: 0.516959
# Early stopping, best iteration is:
# [1049]	training's rmse: 0.329031	valid_1's rmse: 0.516484
# Model training59.695[s]
# score: 0.51648
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.64446	valid_1's rmse: 0.650055
# [200]	training's rmse: 0.50179	valid_1's rmse: 0.526039
# [300]	training's rmse: 0.45608	valid_1's rmse: 0.498974
# [400]	training's rmse: 0.4301	valid_1's rmse: 0.490571
# [500]	training's rmse: 0.40967	valid_1's rmse: 0.486454
# [600]	training's rmse: 0.391889	valid_1's rmse: 0.484517
# [700]	training's rmse: 0.376146	valid_1's rmse: 0.483077
# [800]	training's rmse: 0.361586	valid_1's rmse: 0.482179
# [900]	training's rmse: 0.348388	valid_1's rmse: 0.481779
# [1000]	training's rmse: 0.335788	valid_1's rmse: 0.481921
# [1100]	training's rmse: 0.324354	valid_1's rmse: 0.481611
# [1200]	training's rmse: 0.313223	valid_1's rmse: 0.481872
# Early stopping, best iteration is:
# [1079]	training's rmse: 0.326687	valid_1's rmse: 0.481535
# Model training61.057[s]
# score: 0.48153
# oof score:  0.486628

# %%
score_lgb.loc[score_lgb.fold == "oof"]
# Out:
#     seed fold  rmse score
# 15   950  oof    0.487028
# 31   951  oof    0.487998
# 47   952  oof    0.486897
# 63   953  oof    0.488134
# 79   954  oof    0.487170
# 95   955  oof    0.486973
# 111  956  oof    0.487901
# 127  957  oof    0.487479
# 143  958  oof    0.486979
# 159  959  oof    0.488162
# 175  960  oof    0.487265
# 191  961  oof    0.486671
# 207  962  oof    0.486924
# 223  963  oof    0.487487
# 239  964  oof    0.486924
# 255  965  oof    0.487436
# 271  966  oof    0.486262
# 287  967  oof    0.487782
# 303  968  oof    0.487473
# 319  969  oof    0.487494
# 335  970  oof    0.486628
# 336  avg  oof    0.484832

# %%
order = list(feat_imps_lgb.groupby("feature").mean().sort_values("importance", ascending=False).index)
plt.figure(figsize=(10, 120))
sns.barplot(x="importance", y="feature", data=feat_imps_lgb, order=order)
plt.title("{} importance".format("lgb"))
plt.tight_layout()

# %%
stage1 = pd.read_csv(OUTDIR / 'stage1.csv')
stage1['pred_888feat_lgb6'] = np.nan
stage1['pred_888feat_lgb6'][:t] = oof_pred_lgb
stage1['pred_888feat_lgb6'][t:] = test_pred_lgb
stage1.to_csv(OUTDIR / 'stage1.csv', index=False)

# %%
output = np.expm1(test_pred_lgb)
df_sub = pd.DataFrame()
df_sub["id"] = df_test["id"]
df_sub["cites"] = output
df_sub.to_csv(OUTDIR / 'stage1_888feat_lgb6.csv', index=False)
